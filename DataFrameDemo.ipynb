# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.arange(9).reshape(3,3))

# %%
df
# Out:
#    0  1  2
# 0  0  1  2
# 1  3  4  5
# 2  6  7  8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
# 0    3 non-null int32
# 1    3 non-null int32
# 2    3 non-null int32
# dtypes: int32(3)
# memory usage: 116.0 bytes

# %%
df = pd.DataFrame(np.arange(9).reshape(3,3), columns=list("ABC"))

# %%
df
# Out:
#    A  B  C
# 0  0  1  2
# 1  3  4  5
# 2  6  7  8

# %%
df['A']
# Out:
# 0    0
# 1    3
# 2    6
# Name: A, dtype: int32

# %%
df[['A','C']]
# Out:
#    A  C
# 0  0  2
# 1  3  5
# 2  6  8

# %%
df['A'][1]
# Out:
# 3

# %%
df.A  # Not recom.
# Out:
# 0    0
# 1    3
# 2    6
# Name: A, dtype: int32

# %%
df[:2]['A']
# Out:
# 0    0
# 1    3
# Name: A, dtype: int32

# %%
df[:1][:]
# Out:
#    A  B  C
# 0  0  1  2

# %%
sales = pd.read_csv('sales.txt')

# %%
sales
# Out:
#   Month  Book City  Units
# 0   JAN  B100  VZG   10.0
# 1   FEB  B100  VZG    4.0
# 2   MAR  B100  VZG   13.0
# 3   JAN  B100  HYD   30.0
# 4   FEB  B100  HYD   40.0
# 5   MAR  B100  HYD   10.0
# 6   JAN  B200  VZG   14.0
# 7   FEB  B200  HYD    NaN
# 8   MAR  B200  NaN    4.0

# %%
sales.describe()
# Out:
#           Units
# count   8.00000
# mean   15.62500
# std    12.78322
# min     4.00000
# 25%     8.50000
# 50%    11.50000
# 75%    18.00000
# max    40.00000

# %%
sales.describe(include='all')
# Out:
#        Month  Book City     Units
# count      9     9    8   8.00000
# unique     3     2    2       NaN
# top      FEB  B100  HYD       NaN
# freq       3     6    4       NaN
# mean     NaN   NaN  NaN  15.62500
# std      NaN   NaN  NaN  12.78322
# min      NaN   NaN  NaN   4.00000
# 25%      NaN   NaN  NaN   8.50000
# 50%      NaN   NaN  NaN  11.50000
# 75%      NaN   NaN  NaN  18.00000
# max      NaN   NaN  NaN  40.00000

# %%
sales
# Out:
#   Month  Book City  Units
# 0   JAN  B100  VZG   10.0
# 1   FEB  B100  VZG    4.0
# 2   MAR  B100  VZG   13.0
# 3   JAN  B100  HYD   30.0
# 4   FEB  B100  HYD   40.0
# 5   MAR  B100  HYD   10.0
# 6   JAN  B200  VZG   14.0
# 7   FEB  B200  HYD    NaN
# 8   MAR  B200  NaN    4.0

# %%
sales
# Out:
#   Month  Book City  Units
# 0   JAN  B100  VZG   10.0
# 1   FEB  B100  VZG    4.0
# 2   MAR  B100  VZG   13.0
# 3   JAN  B100  HYD   30.0
# 4   FEB  B100  HYD   40.0
# 5   MAR  B100  HYD   10.0
# 6   JAN  B200  VZG   14.0
# 7   FEB  B200  HYD    NaN
# 8   MAR  B200  NaN    4.0

# %%
sales.loc[0,'Units']
# Out:
# 10.0

# %%
sales.head()
# Out:
#   Month  Book City  Units
# 0   JAN  B100  VZG   10.0
# 1   FEB  B100  VZG    4.0
# 2   MAR  B100  VZG   13.0
# 3   JAN  B100  HYD   30.0
# 4   FEB  B100  HYD   40.0

# %%
sales.loc[ sales.City == 'VZG' , ['Book','Units'] ]
# Out:
#    Book  Units
# 0  B100   10.0
# 1  B100    4.0
# 2  B100   13.0
# 6  B200   14.0

# %%
units = sales.loc[ : , 'Units']

# %%
type(units)
# Out:
# pandas.core.series.Series

# %%
det = sales.loc[ : , ['Book','Units']]

# %%
type(det)
# Out:
# pandas.core.frame.DataFrame

# %%
sales.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
sales.iloc[0,:]
# Out:
# Month     JAN
# Book     B100
# City      VZG
# Units      10
# Name: 0, dtype: object

# %% [markdown]
# ## Read data about countries

# %%
import requests

# %%
resp = requests.get("https://restcountries.eu/rest/v2/all")

# %%
cdf = pd.DataFrame(resp.json())

# %%
cdf.head()
# Out:
#   alpha2Code alpha3Code                                       altSpellings  \
# 0         AF        AFG                                   [AF, Afġānistān]
# 1         AX        ALA                    [AX, Aaland, Aland, Ahvenanmaa]
# 2         AL        ALB                [AL, Shqipëri, Shqipëria, Shqipnia]
# 3         DZ        DZA                              [DZ, Dzayer, Algérie]
# 4         AS        ASM  [AS, Amerika Sāmoa, Amelika Sāmoa, Sāmoa Amelika]
#
#         area                              borders callingCodes    capital  \
# 0   652230.0       [IRN, PAK, TKM, UZB, TJK, CHN]         [93]      Kabul
# 1     1580.0                                   []        [358]  Mariehamn
# 2    28748.0                 [MNE, GRC, MKD, KOS]        [355]     Tirana
# 3  2381741.0  [TUN, LBY, NER, ESH, MRT, MLI, MAR]        [213]    Algiers
# 4      199.0                                   []       [1684]  Pago Pago
#
#   cioc                                         currencies          demonym  \
# 0  AFG  [{'code': 'AFN', 'name': 'Afghan afghani', 'sy...           Afghan
# 1        [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]         Ålandish
# 2  ALB  [{'code': 'ALL', 'name': 'Albanian lek', 'symb...         Albanian
# 3  ALG  [{'code': 'DZD', 'name': 'Algerian dinar', 'sy...         Algerian
# 4  ASA  [{'code': 'USD', 'name': 'United State Dollar'...  American Samoan
#
#                          ...                                    name  \
# 0                        ...                             Afghanistan
# 1                        ...                           Åland Islands
# 2                        ...                                 Albania
# 3                        ...                                 Algeria
# 4                        ...                          American Samoa
#
#        nativeName numericCode population   region  \
# 0       افغانستان         004   27657145     Asia
# 1           Åland         248      28875   Europe
# 2       Shqipëria         008    2886026   Europe
# 3         الجزائر         012   40400000   Africa
# 4  American Samoa         016      57100  Oceania
#
#                                        regionalBlocs        subregion  \
# 0  [{'acronym': 'SAARC', 'name': 'South Asian Ass...    Southern Asia
# 1  [{'acronym': 'EU', 'name': 'European Union', '...  Northern Europe
# 2  [{'acronym': 'CEFTA', 'name': 'Central Europea...  Southern Europe
# 3  [{'acronym': 'AU', 'name': 'African Union', 'o...  Northern Africa
# 4                                                 []        Polynesia
#
#      timezones topLevelDomain  \
# 0  [UTC+04:30]          [.af]
# 1  [UTC+02:00]          [.ax]
# 2  [UTC+01:00]          [.al]
# 3  [UTC+01:00]          [.dz]
# 4  [UTC-11:00]          [.as]
#
#                                         translations
# 0  {'de': 'Afghanistan', 'es': 'Afganistán', 'fr'...
# 1  {'de': 'Åland', 'es': 'Alandia', 'fr': 'Åland'...
# 2  {'de': 'Albanien', 'es': 'Albania', 'fr': 'Alb...
# 3  {'de': 'Algerien', 'es': 'Argelia', 'fr': 'Alg...
# 4  {'de': 'Amerikanisch-Samoa', 'es': 'Samoa Amer...
#
# [5 rows x 24 columns]

# %%
cdf.describe()
# Out:
#                area        gini    population
# count  2.400000e+02  153.000000  2.500000e+02
# mean   6.262107e+05   40.177124  2.939655e+07
# std    1.950028e+06    9.265119  1.244578e+08
# min    4.400000e-01   24.000000  0.000000e+00
# 25%    1.533250e+03   33.700000  2.029030e+05
# 50%    7.100650e+04   38.600000  4.648734e+06
# 75%    4.146432e+05   46.200000  1.803955e+07
# max    1.712444e+07   65.800000  1.377422e+09

# %%
cdf['population']
# Out:
# 0       27657145
# 1          28875
# 2        2886026
# 3       40400000
# 4          57100
# 5          78014
# 6       25868000
# 7          13452
# 8           1000
# 9          86295
# 10      43590400
# 11       2994400
# 12        107394
# 13      24117360
# 14       8725931
# 15       9730500
# 16        378040
# 17       1404900
# 18     161006790
# 19        285000
# 20       9498700
# 21      11319511
# 22        370300
# 23      10653654
# 24         61954
# 25        775620
# 26      10985059
# 27         17408
# 28       3531159
# 29       2141206
#          ...
# 220     18564000
# 221     23503349
# 222      8593600
# 223     55155000
# 224     65327652
# 225      1167242
# 226      7143000
# 227         1411
# 228       103252
# 229      1349667
# 230     11154400
# 231     78741053
# 232      4751120
# 233        31458
# 234        10640
# 235     33860700
# 236     42692393
# 237      9856000
# 238     65110000
# 239    323947000
# 240      3480222
# 241     31576400
# 242       277500
# 243     31028700
# 244     92700000
# 245        11750
# 246       510713
# 247     27478000
# 248     15933883
# 249     14240168
# Name: population, Length: 250, dtype: int64

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 24 columns):
# alpha2Code        250 non-null object
# alpha3Code        250 non-null object
# altSpellings      250 non-null object
# area              240 non-null float64
# borders           250 non-null object
# callingCodes      250 non-null object
# capital           250 non-null object
# cioc              247 non-null object
# currencies        250 non-null object
# demonym           250 non-null object
# flag              250 non-null object
# gini              153 non-null float64
# languages         250 non-null object
# latlng            250 non-null object
# name              250 non-null object
# nativeName        250 non-null object
# numericCode       249 non-null object
# population        250 non-null int64
# region            250 non-null object
# regionalBlocs     250 non-null object
# subregion         250 non-null object
# timezones         250 non-null object
# topLevelDomain    250 non-null object
# translations      250 non-null object
# dtypes: float64(2), int64(1), object(21)
# memory usage: 47.0+ KB

# %% [markdown]
# ## 11-FEB

# %%
# cdf[ ['alpha3Code','name','capital','population','area']].head()
cdf.loc[:5, ['alpha3Code','name','capital','population','area']]
# Out:
#   alpha3Code            name           capital  population       area
# 0        AFG     Afghanistan             Kabul    27657145   652230.0
# 1        ALA   Åland Islands         Mariehamn       28875     1580.0
# 2        ALB         Albania            Tirana     2886026    28748.0
# 3        DZA         Algeria           Algiers    40400000  2381741.0
# 4        ASM  American Samoa         Pago Pago       57100      199.0
# 5        AND         Andorra  Andorra la Vella       78014      468.0

# %%
def get_codes(lst):
    return lst[0]['code']

# %%
c = cdf['currencies'].apply(get_codes).head()

# %%
c
# Out:
# 0    AFN
# 1    EUR
# 2    ALL
# 3    DZD
# 4    USD
# Name: currencies, dtype: object

# %%
def get_all_codes(lst):
    codes = []
    for c in lst:
        if 'code' in c and c['code'] is not None:
           codes.append( c['code'])
        
    return ",".join(codes)

# %%
cdf['currencies'].apply(get_all_codes).head(25)
# Out:
# 0         AFN
# 1         EUR
# 2         ALL
# 3         DZD
# 4         USD
# 5         EUR
# 6         AOA
# 7         XCD
# 8     AUD,GBP
# 9         XCD
# 10        ARS
# 11        AMD
# 12        AWG
# 13        AUD
# 14        EUR
# 15        AZN
# 16        BSD
# 17        BHD
# 18        BDT
# 19        BBD
# 20    BYN,BYR
# 21        EUR
# 22        BZD
# 23        XOF
# 24        BMD
# Name: currencies, dtype: object

# %%
cdf.loc[8,'currencies']
# Out:
# [{'code': 'AUD', 'name': 'Australian dollar', 'symbol': '$'},
#  {'code': 'GBP', 'name': 'British pound', 'symbol': '£'}]

# %%
cdf.at[8,'currencies']
# Out:
# [{'code': 'AUD', 'name': 'Australian dollar', 'symbol': '$'},
#  {'code': 'GBP', 'name': 'British pound', 'symbol': '£'}]

# %%
cor = 10000000

# %%
cdf[cdf['borders'].str]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-c4ca019fbb22> in <module>
# ----> 1 cdf[cdf['borders'].str]
#
# d:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# d:\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# d:\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# d:\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4112         if self.items.is_unique:
#    4113
# -> 4114             if not isna(item):
#    4115                 loc = self.items.get_loc(item)
#    4116             else:
#
# d:\Anaconda3\lib\site-packages\pandas\core\dtypes\missing.py in isna(obj)
#     104     Name: 1, dtype: bool
#     105     """
# --> 106     return _isna(obj)
#     107
#     108
#
# d:\Anaconda3\lib\site-packages\pandas\core\dtypes\missing.py in _isna_new(obj)
#     120         return _isna_ndarraylike(obj)
#     121     elif isinstance(obj, ABCGeneric):
# --> 122         return obj._constructor(obj._data.isna(func=isna))
#     123     elif isinstance(obj, list):
#     124         return _isna_ndarraylike(np.asarray(obj, dtype=object))
#
# AttributeError: 'StringMethods' object has no attribute '_constructor'

# %%
def  has_border(lst):
    return len(lst) > 0

def  has_no_border(lst):
     return  len(lst) == 0

# %%
cdf[cdf['borders'].apply(has_no_border)].head()

# %%
cdf.info()

# %%
cdf['area'].sort_values(ascending=False).head()

# %%
top5 =

# %%
cdf.loc[top5.index,['name','region','area','population']]

# %%
cdf[ (cdf['region'] == 'Asia') & (cdf['area'] > 3000000) ]

# %%
cdf.at[0,'alpha3Code']

# %%
cdf.sample(n=10)

# %%
cdf[ ['name','capital','region']].isin({'region': ['Asia','Africa']})

# %%
cdf.info()

# %%
top_den_cl = (cdf['population'] / cdf['area']).sort_values(ascending=False).head()
top_den_cl

# %%
cdf.loc[top_den_cl.index]

# %%
nd = pd.DataFrame({'name' : cdf['name'], 'borders' : cdf['borders'].str.join(",")})

# %%
nd

# %%
sales

# %%
sales.loc[:,['City','Units']].apply(lambda s : s.count())

# %%
sales.applymap(lambda v : 'Null' if v is np.nan else v)

# %%
sales

# %%
sales.info()

# %%
sales = sales.append( {'Month':'FEB','Book' : 'B300', 'City': 'VZG','Units' : 10}, ignore_index=True)

# %%
sales

# %%
sales.loc[:5, ['Year']] = 2018

# %%
sales['Diff'] = sales['Units'] - 5

# %%
sales.drop(['Year','Diff'], axis=1, inplace=True)

# %%
sales

# %%
cdf['strborders'] = cdf['borders'].str.join(",")

# %%
cdf['strborders'].head()
# Out:
# 0        IRN,PAK,TKM,UZB,TJK,CHN
# 1
# 2                MNE,GRC,MKD,KOS
# 3    TUN,LBY,NER,ESH,MRT,MLI,MAR
# 4
# Name: strborders, dtype: object

# %%
cdf.head()
# Out:
#   alpha2Code alpha3Code                                       altSpellings  \
# 0         AF        AFG                                   [AF, Afġānistān]
# 1         AX        ALA                    [AX, Aaland, Aland, Ahvenanmaa]
# 2         AL        ALB                [AL, Shqipëri, Shqipëria, Shqipnia]
# 3         DZ        DZA                              [DZ, Dzayer, Algérie]
# 4         AS        ASM  [AS, Amerika Sāmoa, Amelika Sāmoa, Sāmoa Amelika]
#
#         area                              borders callingCodes    capital  \
# 0   652230.0       [IRN, PAK, TKM, UZB, TJK, CHN]         [93]      Kabul
# 1     1580.0                                   []        [358]  Mariehamn
# 2    28748.0                 [MNE, GRC, MKD, KOS]        [355]     Tirana
# 3  2381741.0  [TUN, LBY, NER, ESH, MRT, MLI, MAR]        [213]    Algiers
# 4      199.0                                   []       [1684]  Pago Pago
#
#   cioc                                         currencies          demonym  \
# 0  AFG  [{'code': 'AFN', 'name': 'Afghan afghani', 'sy...           Afghan
# 1        [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]         Ålandish
# 2  ALB  [{'code': 'ALL', 'name': 'Albanian lek', 'symb...         Albanian
# 3  ALG  [{'code': 'DZD', 'name': 'Algerian dinar', 'sy...         Algerian
# 4  ASA  [{'code': 'USD', 'name': 'United State Dollar'...  American Samoan
#
#               ...                   nativeName  numericCode population  \
# 0             ...                    افغانستان          004   27657145
# 1             ...                        Åland          248      28875
# 2             ...                    Shqipëria          008    2886026
# 3             ...                      الجزائر          012   40400000
# 4             ...               American Samoa          016      57100
#
#     region                                      regionalBlocs  \
# 0     Asia  [{'acronym': 'SAARC', 'name': 'South Asian Ass...
# 1   Europe  [{'acronym': 'EU', 'name': 'European Union', '...
# 2   Europe  [{'acronym': 'CEFTA', 'name': 'Central Europea...
# 3   Africa  [{'acronym': 'AU', 'name': 'African Union', 'o...
# 4  Oceania                                                 []
#
#          subregion    timezones  topLevelDomain  \
# 0    Southern Asia  [UTC+04:30]           [.af]
# 1  Northern Europe  [UTC+02:00]           [.ax]
# 2  Southern Europe  [UTC+01:00]           [.al]
# 3  Northern Africa  [UTC+01:00]           [.dz]
# 4        Polynesia  [UTC-11:00]           [.as]
#
#                                         translations  \
# 0  {'de': 'Afghanistan', 'es': 'Afganistán', 'fr'...
# 1  {'de': 'Åland', 'es': 'Alandia', 'fr': 'Åland'...
# 2  {'de': 'Albanien', 'es': 'Albania', 'fr': 'Alb...
# 3  {'de': 'Algerien', 'es': 'Argelia', 'fr': 'Alg...
# 4  {'de': 'Amerikanisch-Samoa', 'es': 'Samoa Amer...
#
#                     strborders
# 0      IRN,PAK,TKM,UZB,TJK,CHN
# 1
# 2              MNE,GRC,MKD,KOS
# 3  TUN,LBY,NER,ESH,MRT,MLI,MAR
# 4
#
# [5 rows x 25 columns]

# %%
df = pd.DataFrame({'c1':[1,2], 'c2': [100,200]})

# %%
df
# Out:
#    c1   c2
# 0   1  100
# 1   2  200

# %%
df = df.set_index('c1')

# %%
df
# Out:
#      c2
# c1
# 1   100
# 2   200

# %%
df.loc[2,:]
# Out:
# c2    200
# Name: 2, dtype: int64

# %%
cdf.set_index(['alpha3Code'])
# Out:
#            alpha2Code                                       altSpellings  \
# alpha3Code
# AFG                AF                                   [AF, Afġānistān]
# ALA                AX                    [AX, Aaland, Aland, Ahvenanmaa]
# ALB                AL                [AL, Shqipëri, Shqipëria, Shqipnia]
# DZA                DZ                              [DZ, Dzayer, Algérie]
# ASM                AS  [AS, Amerika Sāmoa, Amelika Sāmoa, Sāmoa Amelika]
# AND                AD  [AD, Principality of Andorra, Principat d'Ando...
# AGO                AO    [AO, República de Angola, ʁɛpublika de an'ɡɔla]
# AIA                AI                                               [AI]
# ATA                AQ                                                 []
# ATG                AG                                               [AG]
# ARG                AR      [AR, Argentine Republic, República Argentina]
# ARM                AM  [AM, Hayastan, Republic of Armenia, Հայաստանի ...
# ABW                AW                                               [AW]
# AUS                AU                                               [AU]
# AUT                AT          [AT, Österreich, Osterreich, Oesterreich]
# AZE                AZ  [AZ, Republic of Azerbaijan, Azərbaycan Respub...
# BHS                BS                  [BS, Commonwealth of the Bahamas]
# BHR                BH      [BH, Kingdom of Bahrain, Mamlakat al-Baḥrayn]
# BGD                BD  [BD, People's Republic of Bangladesh, Gônôprôj...
# BRB                BB                                               [BB]
# BLR                BY  [BY, Bielaruś, Republic of Belarus, Белоруссия...
# BEL                BE  [BE, België, Belgie, Belgien, Belgique, Kingdo...
# BLZ                BZ                                               [BZ]
# BEN                BJ       [BJ, Republic of Benin, République du Bénin]
# BMU                BM  [BM, The Islands of Bermuda, The Bermudas, Som...
# BTN                BT                            [BT, Kingdom of Bhutan]
# BOL                BO  [BO, Buliwya, Wuliwya, Plurinational State of ...
# BES                BQ                                      [BQ, Boneiru]
# BIH                BA      [BA, Bosnia-Herzegovina, Босна и Херцеговина]
# BWA                BW   [BW, Republic of Botswana, Lefatshe la Botswana]
# ...               ...                                                ...
# SYR                SY  [SY, Syrian Arab Republic, Al-Jumhūrīyah Al-ʻA...
# TWN                TW  [TW, Táiwān, Republic of China, 中華民國, Zhōnghuá...
# TJK                TJ  [TJ, Toçikiston, Republic of Tajikistan, Ҷумҳу...
# TZA                TZ  [TZ, United Republic of Tanzania, Jamhuri ya M...
# THA                TH  [TH, Prathet, Thai, Kingdom of Thailand, ราชอา...
# TLS                TL  [TL, East Timor, Democratic Republic of Timor-...
# TGO                TG  [TG, Togolese, Togolese Republic, République T...
# TKL                TK                                               [TK]
# TON                TO                                               [TO]
# TTO                TT              [TT, Republic of Trinidad and Tobago]
# TUN                TN  [TN, Republic of Tunisia, al-Jumhūriyyah at-Tū...
# TUR                TR  [TR, Turkiye, Republic of Turkey, Türkiye Cumh...
# TKM                TM                                               [TM]
# TCA                TC                                               [TC]
# TUV                TV                                               [TV]
# UGA                UG        [UG, Republic of Uganda, Jamhuri ya Uganda]
# UKR                UA                                     [UA, Ukrayina]
# ARE                AE                                          [AE, UAE]
# GBR                GB                            [GB, UK, Great Britain]
# USA                US                [US, USA, United States of America]
# URY                UY  [UY, Oriental Republic of Uruguay, República O...
# UZB                UZ  [UZ, Republic of Uzbekistan, O‘zbekiston Respu...
# VUT                VU  [VU, Republic of Vanuatu, Ripablik blong Vanua...
# VEN                VE  [VE, Bolivarian Republic of Venezuela, Repúbli...
# VNM                VN  [VN, Socialist Republic of Vietnam, Cộng hòa X...
# WLF                WF  [WF, Territory of the Wallis and Futuna Island...
# ESH                EH                            [EH, Taneẓroft Tutrimt]
# YEM                YE  [YE, Yemeni Republic, al-Jumhūriyyah al-Yamani...
# ZMB                ZM                           [ZM, Republic of Zambia]
# ZWE                ZW                         [ZW, Republic of Zimbabwe]
#
#                   area                                   borders callingCodes  \
# alpha3Code
# AFG           652230.0            [IRN, PAK, TKM, UZB, TJK, CHN]         [93]
# ALA             1580.0                                        []        [358]
# ALB            28748.0                      [MNE, GRC, MKD, KOS]        [355]
# DZA          2381741.0       [TUN, LBY, NER, ESH, MRT, MLI, MAR]        [213]
# ASM              199.0                                        []       [1684]
# AND              468.0                                [FRA, ESP]        [376]
# AGO          1246700.0                      [COG, COD, ZMB, NAM]        [244]
# AIA               91.0                                        []       [1264]
# ATA         14000000.0                                        []        [672]
# ATG              442.0                                        []       [1268]
# ARG          2780400.0                 [BOL, BRA, CHL, PRY, URY]         [54]
# ARM            29743.0                      [AZE, GEO, IRN, TUR]        [374]
# ABW              180.0                                        []        [297]
# AUS          7692024.0                                        []         [61]
# AUT            83871.0  [CZE, DEU, HUN, ITA, LIE, SVK, SVN, CHE]         [43]
# AZE            86600.0                 [ARM, GEO, IRN, RUS, TUR]        [994]
# BHS            13943.0                                        []       [1242]
# BHR              765.0                                        []        [973]
# BGD           147570.0                                [MMR, IND]        [880]
# BRB              430.0                                        []       [1246]
# BLR           207600.0                 [LVA, LTU, POL, RUS, UKR]        [375]
# BEL            30528.0                      [FRA, DEU, LUX, NLD]         [32]
# BLZ            22966.0                                [GTM, MEX]        [501]
# BEN           112622.0                      [BFA, NER, NGA, TGO]        [229]
# BMU               54.0                                        []       [1441]
# BTN            38394.0                                [CHN, IND]        [975]
# BOL          1098581.0                 [ARG, BRA, CHL, PRY, PER]        [591]
# BES              294.0                                        []       [5997]
# BIH            51209.0                           [HRV, MNE, SRB]        [387]
# BWA           582000.0                      [NAM, ZAF, ZMB, ZWE]        [267]
# ...                ...                                       ...          ...
# SYR           185180.0                 [IRQ, ISR, JOR, LBN, TUR]        [963]
# TWN            36193.0                                        []        [886]
# TJK           143100.0                      [AFG, CHN, KGZ, UZB]        [992]
# TZA           945087.0  [BDI, COD, KEN, MWI, MOZ, RWA, UGA, ZMB]        [255]
# THA           513120.0                      [MMR, KHM, LAO, MYS]         [66]
# TLS            14874.0                                     [IDN]        [670]
# TGO            56785.0                           [BEN, BFA, GHA]        [228]
# TKL               12.0                                        []        [690]
# TON              747.0                                        []        [676]
# TTO             5130.0                                        []       [1868]
# TUN           163610.0                                [DZA, LBY]        [216]
# TUR           783562.0  [ARM, AZE, BGR, GEO, GRC, IRN, IRQ, SYR]         [90]
# TKM           488100.0                      [AFG, IRN, KAZ, UZB]        [993]
# TCA              948.0                                        []       [1649]
# TUV               26.0                                        []        [688]
# UGA           241550.0                 [COD, KEN, RWA, SSD, TZA]        [256]
# UKR           603700.0       [BLR, HUN, MDA, POL, ROU, RUS, SVK]        [380]
# ARE            83600.0                                [OMN, SAU]        [971]
# GBR           242900.0                                     [IRL]         [44]
# USA          9629091.0                                [CAN, MEX]          [1]
# URY           181034.0                                [ARG, BRA]        [598]
# UZB           447400.0                 [AFG, KAZ, KGZ, TJK, TKM]        [998]
# VUT            12189.0                                        []        [678]
# VEN           916445.0                           [BRA, COL, GUY]         [58]
# VNM           331212.0                           [KHM, CHN, LAO]         [84]
# WLF              142.0                                        []        [681]
# ESH           266000.0                           [DZA, MRT, MAR]        [212]
# YEM           527968.0                                [OMN, SAU]        [967]
# ZMB           752612.0  [AGO, BWA, COD, MWI, MOZ, NAM, TZA, ZWE]        [260]
# ZWE           390757.0                      [BWA, MOZ, ZAF, ZMB]        [263]
#
#                      capital  cioc  \
# alpha3Code
# AFG                    Kabul   AFG
# ALA                Mariehamn
# ALB                   Tirana   ALB
# DZA                  Algiers   ALG
# ASM                Pago Pago   ASA
# AND         Andorra la Vella   AND
# AGO                   Luanda   ANG
# AIA               The Valley
# ATA
# ATG             Saint John's   ANT
# ARG             Buenos Aires   ARG
# ARM                  Yerevan   ARM
# ABW               Oranjestad   ARU
# AUS                 Canberra   AUS
# AUT                   Vienna   AUT
# AZE                     Baku   AZE
# BHS                   Nassau   BAH
# BHR                   Manama   BRN
# BGD                    Dhaka   BAN
# BRB               Bridgetown   BAR
# BLR                    Minsk   BLR
# BEL                 Brussels   BEL
# BLZ                 Belmopan   BIZ
# BEN               Porto-Novo   BEN
# BMU                 Hamilton   BER
# BTN                  Thimphu   BHU
# BOL                    Sucre   BOL
# BES               Kralendijk  None
# BIH                 Sarajevo   BIH
# BWA                 Gaborone   BOT
# ...                      ...   ...
# SYR                 Damascus   SYR
# TWN                   Taipei   TPE
# TJK                 Dushanbe   TJK
# TZA                   Dodoma   TAN
# THA                  Bangkok   THA
# TLS                     Dili   TLS
# TGO                     Lomé   TOG
# TKL                  Fakaofo
# TON               Nuku'alofa   TGA
# TTO            Port of Spain   TTO
# TUN                    Tunis   TUN
# TUR                   Ankara   TUR
# TKM                 Ashgabat   TKM
# TCA            Cockburn Town
# TUV                 Funafuti   TUV
# UGA                  Kampala   UGA
# UKR                     Kiev   UKR
# ARE                Abu Dhabi   UAE
# GBR                   London   GBR
# USA         Washington, D.C.   USA
# URY               Montevideo   URU
# UZB                 Tashkent   UZB
# VUT                Port Vila   VAN
# VEN                  Caracas   VEN
# VNM                    Hanoi   VIE
# WLF                 Mata-Utu
# ESH                 El Aaiún
# YEM                   Sana'a   YEM
# ZMB                   Lusaka   ZAM
# ZWE                   Harare   ZIM
#
#                                                    currencies  \
# alpha3Code
# AFG         [{'code': 'AFN', 'name': 'Afghan afghani', 'sy...
# ALA          [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]
# ALB         [{'code': 'ALL', 'name': 'Albanian lek', 'symb...
# DZA         [{'code': 'DZD', 'name': 'Algerian dinar', 'sy...
# ASM         [{'code': 'USD', 'name': 'United State Dollar'...
# AND          [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]
# AGO         [{'code': 'AOA', 'name': 'Angolan kwanza', 'sy...
# AIA         [{'code': 'XCD', 'name': 'East Caribbean dolla...
# ATA         [{'code': 'AUD', 'name': 'Australian dollar', ...
# ATG         [{'code': 'XCD', 'name': 'East Caribbean dolla...
# ARG         [{'code': 'ARS', 'name': 'Argentine peso', 'sy...
# ARM         [{'code': 'AMD', 'name': 'Armenian dram', 'sym...
# ABW         [{'code': 'AWG', 'name': 'Aruban florin', 'sym...
# AUS         [{'code': 'AUD', 'name': 'Australian dollar', ...
# AUT          [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]
# AZE         [{'code': 'AZN', 'name': 'Azerbaijani manat', ...
# BHS         [{'code': 'BSD', 'name': 'Bahamian dollar', 's...
# BHR         [{'code': 'BHD', 'name': 'Bahraini dinar', 'sy...
# BGD         [{'code': 'BDT', 'name': 'Bangladeshi taka', '...
# BRB         [{'code': 'BBD', 'name': 'Barbadian dollar', '...
# BLR         [{'code': 'BYN', 'name': 'New Belarusian ruble...
# BEL          [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]
# BLZ         [{'code': 'BZD', 'name': 'Belize dollar', 'sym...
# BEN         [{'code': 'XOF', 'name': 'West African CFA fra...
# BMU         [{'code': 'BMD', 'name': 'Bermudian dollar', '...
# BTN         [{'code': 'BTN', 'name': 'Bhutanese ngultrum',...
# BOL         [{'code': 'BOB', 'name': 'Bolivian boliviano',...
# BES         [{'code': 'USD', 'name': 'United States dollar...
# BIH         [{'code': 'BAM', 'name': 'Bosnia and Herzegovi...
# BWA         [{'code': 'BWP', 'name': 'Botswana pula', 'sym...
# ...                                                       ...
# SYR         [{'code': 'SYP', 'name': 'Syrian pound', 'symb...
# TWN         [{'code': 'TWD', 'name': 'New Taiwan dollar', ...
# TJK         [{'code': 'TJS', 'name': 'Tajikistani somoni',...
# TZA         [{'code': 'TZS', 'name': 'Tanzanian shilling',...
# THA         [{'code': 'THB', 'name': 'Thai baht', 'symbol'...
# TLS         [{'code': 'USD', 'name': 'United States dollar...
# TGO         [{'code': 'XOF', 'name': 'West African CFA fra...
# TKL         [{'code': 'NZD', 'name': 'New Zealand dollar',...
# TON         [{'code': 'TOP', 'name': 'Tongan paʻanga', 'sy...
# TTO         [{'code': 'TTD', 'name': 'Trinidad and Tobago ...
# TUN         [{'code': 'TND', 'name': 'Tunisian dinar', 'sy...
# TUR         [{'code': 'TRY', 'name': 'Turkish lira', 'symb...
# TKM         [{'code': 'TMT', 'name': 'Turkmenistan manat',...
# TCA         [{'code': 'USD', 'name': 'United States dollar...
# TUV         [{'code': 'AUD', 'name': 'Australian dollar', ...
# UGA         [{'code': 'UGX', 'name': 'Ugandan shilling', '...
# UKR         [{'code': 'UAH', 'name': 'Ukrainian hryvnia', ...
# ARE         [{'code': 'AED', 'name': 'United Arab Emirates...
# GBR         [{'code': 'GBP', 'name': 'British pound', 'sym...
# USA         [{'code': 'USD', 'name': 'United States dollar...
# URY         [{'code': 'UYU', 'name': 'Uruguayan peso', 'sy...
# UZB         [{'code': 'UZS', 'name': 'Uzbekistani so'm', '...
# VUT         [{'code': 'VUV', 'name': 'Vanuatu vatu', 'symb...
# VEN         [{'code': 'VEF', 'name': 'Venezuelan bolívar',...
# VNM         [{'code': 'VND', 'name': 'Vietnamese đồng', 's...
# WLF         [{'code': 'XPF', 'name': 'CFP franc', 'symbol'...
# ESH         [{'code': 'MAD', 'name': 'Moroccan dirham', 's...
# YEM         [{'code': 'YER', 'name': 'Yemeni rial', 'symbo...
# ZMB         [{'code': 'ZMW', 'name': 'Zambian kwacha', 'sy...
# ZWE         [{'code': 'BWP', 'name': 'Botswana pula', 'sym...
#
#                                demonym                                   flag  \
# alpha3Code
# AFG                             Afghan  https://restcountries.eu/data/afg.svg
# ALA                           Ålandish  https://restcountries.eu/data/ala.svg
# ALB                           Albanian  https://restcountries.eu/data/alb.svg
# DZA                           Algerian  https://restcountries.eu/data/dza.svg
# ASM                    American Samoan  https://restcountries.eu/data/asm.svg
# AND                           Andorran  https://restcountries.eu/data/and.svg
# AGO                            Angolan  https://restcountries.eu/data/ago.svg
# AIA                         Anguillian  https://restcountries.eu/data/aia.svg
# ATA                                     https://restcountries.eu/data/ata.svg
# ATG                 Antiguan, Barbudan  https://restcountries.eu/data/atg.svg
# ARG                        Argentinean  https://restcountries.eu/data/arg.svg
# ARM                           Armenian  https://restcountries.eu/data/arm.svg
# ABW                             Aruban  https://restcountries.eu/data/abw.svg
# AUS                         Australian  https://restcountries.eu/data/aus.svg
# AUT                           Austrian  https://restcountries.eu/data/aut.svg
# AZE                        Azerbaijani  https://restcountries.eu/data/aze.svg
# BHS                           Bahamian  https://restcountries.eu/data/bhs.svg
# BHR                           Bahraini  https://restcountries.eu/data/bhr.svg
# BGD                        Bangladeshi  https://restcountries.eu/data/bgd.svg
# BRB                          Barbadian  https://restcountries.eu/data/brb.svg
# BLR                         Belarusian  https://restcountries.eu/data/blr.svg
# BEL                            Belgian  https://restcountries.eu/data/bel.svg
# BLZ                           Belizean  https://restcountries.eu/data/blz.svg
# BEN                           Beninese  https://restcountries.eu/data/ben.svg
# BMU                          Bermudian  https://restcountries.eu/data/bmu.svg
# BTN                          Bhutanese  https://restcountries.eu/data/btn.svg
# BOL                           Bolivian  https://restcountries.eu/data/bol.svg
# BES                              Dutch  https://restcountries.eu/data/bes.svg
# BIH             Bosnian, Herzegovinian  https://restcountries.eu/data/bih.svg
# BWA                           Motswana  https://restcountries.eu/data/bwa.svg
# ...                                ...                                    ...
# SYR                             Syrian  https://restcountries.eu/data/syr.svg
# TWN                          Taiwanese  https://restcountries.eu/data/twn.svg
# TJK                            Tadzhik  https://restcountries.eu/data/tjk.svg
# TZA                          Tanzanian  https://restcountries.eu/data/tza.svg
# THA                               Thai  https://restcountries.eu/data/tha.svg
# TLS                      East Timorese  https://restcountries.eu/data/tls.svg
# TGO                           Togolese  https://restcountries.eu/data/tgo.svg
# TKL                          Tokelauan  https://restcountries.eu/data/tkl.svg
# TON                             Tongan  https://restcountries.eu/data/ton.svg
# TTO                        Trinidadian  https://restcountries.eu/data/tto.svg
# TUN                           Tunisian  https://restcountries.eu/data/tun.svg
# TUR                            Turkish  https://restcountries.eu/data/tur.svg
# TKM                            Turkmen  https://restcountries.eu/data/tkm.svg
# TCA          Turks and Caicos Islander  https://restcountries.eu/data/tca.svg
# TUV                           Tuvaluan  https://restcountries.eu/data/tuv.svg
# UGA                            Ugandan  https://restcountries.eu/data/uga.svg
# UKR                          Ukrainian  https://restcountries.eu/data/ukr.svg
# ARE                            Emirati  https://restcountries.eu/data/are.svg
# GBR                            British  https://restcountries.eu/data/gbr.svg
# USA                           American  https://restcountries.eu/data/usa.svg
# URY                          Uruguayan  https://restcountries.eu/data/ury.svg
# UZB                        Uzbekistani  https://restcountries.eu/data/uzb.svg
# VUT                         Ni-Vanuatu  https://restcountries.eu/data/vut.svg
# VEN                         Venezuelan  https://restcountries.eu/data/ven.svg
# VNM                         Vietnamese  https://restcountries.eu/data/vnm.svg
# WLF         Wallis and Futuna Islander  https://restcountries.eu/data/wlf.svg
# ESH                            Sahrawi  https://restcountries.eu/data/esh.svg
# YEM                             Yemeni  https://restcountries.eu/data/yem.svg
# ZMB                            Zambian  https://restcountries.eu/data/zmb.svg
# ZWE                         Zimbabwean  https://restcountries.eu/data/zwe.svg
#
#                          ...                                    nativeName  \
# alpha3Code               ...
# AFG                      ...                                     افغانستان
# ALA                      ...                                         Åland
# ALB                      ...                                     Shqipëria
# DZA                      ...                                       الجزائر
# ASM                      ...                                American Samoa
# AND                      ...                                       Andorra
# AGO                      ...                                        Angola
# AIA                      ...                                      Anguilla
# ATA                      ...                                    Antarctica
# ATG                      ...                           Antigua and Barbuda
# ARG                      ...                                     Argentina
# ARM                      ...                                      Հայաստան
# ABW                      ...                                         Aruba
# AUS                      ...                                     Australia
# AUT                      ...                                    Österreich
# AZE                      ...                                    Azərbaycan
# BHS                      ...                                       Bahamas
# BHR                      ...                                      ‏البحرين
# BGD                      ...                                    Bangladesh
# BRB                      ...                                      Barbados
# BLR                      ...                                     Белару́сь
# BEL                      ...                                        België
# BLZ                      ...                                        Belize
# BEN                      ...                                         Bénin
# BMU                      ...                                       Bermuda
# BTN                      ...                                     ʼbrug-yul
# BOL                      ...                                       Bolivia
# BES                      ...                                       Bonaire
# BIH                      ...                           Bosna i Hercegovina
# BWA                      ...                                      Botswana
# ...                      ...                                           ...
# SYR                      ...                                         سوريا
# TWN                      ...                                            臺灣
# TJK                      ...                                    Тоҷикистон
# TZA                      ...                                      Tanzania
# THA                      ...                                     ประเทศไทย
# TLS                      ...                                   Timor-Leste
# TGO                      ...                                          Togo
# TKL                      ...                                       Tokelau
# TON                      ...                                         Tonga
# TTO                      ...                           Trinidad and Tobago
# TUN                      ...                                          تونس
# TUR                      ...                                       Türkiye
# TKM                      ...                                  Türkmenistan
# TCA                      ...                      Turks and Caicos Islands
# TUV                      ...                                        Tuvalu
# UGA                      ...                                        Uganda
# UKR                      ...                                       Україна
# ARE                      ...                 دولة الإمارات العربية المتحدة
# GBR                      ...                                United Kingdom
# USA                      ...                                 United States
# URY                      ...                                       Uruguay
# UZB                      ...                                   O‘zbekiston
# VUT                      ...                                       Vanuatu
# VEN                      ...                                     Venezuela
# VNM                      ...                                      Việt Nam
# WLF                      ...                              Wallis et Futuna
# ESH                      ...                               الصحراء الغربية
# YEM                      ...                                       اليَمَن
# ZMB                      ...                                        Zambia
# ZWE                      ...                                      Zimbabwe
#
#            numericCode population    region  \
# alpha3Code
# AFG                004   27657145      Asia
# ALA                248      28875    Europe
# ALB                008    2886026    Europe
# DZA                012   40400000    Africa
# ASM                016      57100   Oceania
# AND                020      78014    Europe
# AGO                024   25868000    Africa
# AIA                660      13452  Americas
# ATA                010       1000     Polar
# ATG                028      86295  Americas
# ARG                032   43590400  Americas
# ARM                051    2994400      Asia
# ABW                533     107394  Americas
# AUS                036   24117360   Oceania
# AUT                040    8725931    Europe
# AZE                031    9730500      Asia
# BHS                044     378040  Americas
# BHR                048    1404900      Asia
# BGD                050  161006790      Asia
# BRB                052     285000  Americas
# BLR                112    9498700    Europe
# BEL                056   11319511    Europe
# BLZ                084     370300  Americas
# BEN                204   10653654    Africa
# BMU                060      61954  Americas
# BTN                064     775620      Asia
# BOL                068   10985059  Americas
# BES                535      17408  Americas
# BIH                070    3531159    Europe
# BWA                072    2141206    Africa
# ...                ...        ...       ...
# SYR                760   18564000      Asia
# TWN                158   23503349      Asia
# TJK                762    8593600      Asia
# TZA                834   55155000    Africa
# THA                764   65327652      Asia
# TLS                626    1167242      Asia
# TGO                768    7143000    Africa
# TKL                772       1411   Oceania
# TON                776     103252   Oceania
# TTO                780    1349667  Americas
# TUN                788   11154400    Africa
# TUR                792   78741053      Asia
# TKM                795    4751120      Asia
# TCA                796      31458  Americas
# TUV                798      10640   Oceania
# UGA                800   33860700    Africa
# UKR                804   42692393    Europe
# ARE                784    9856000      Asia
# GBR                826   65110000    Europe
# USA                840  323947000  Americas
# URY                858    3480222  Americas
# UZB                860   31576400      Asia
# VUT                548     277500   Oceania
# VEN                862   31028700  Americas
# VNM                704   92700000      Asia
# WLF                876      11750   Oceania
# ESH                732     510713    Africa
# YEM                887   27478000      Asia
# ZMB                894   15933883    Africa
# ZWE                716   14240168    Africa
#
#                                                 regionalBlocs  \
# alpha3Code
# AFG         [{'acronym': 'SAARC', 'name': 'South Asian Ass...
# ALA         [{'acronym': 'EU', 'name': 'European Union', '...
# ALB         [{'acronym': 'CEFTA', 'name': 'Central Europea...
# DZA         [{'acronym': 'AU', 'name': 'African Union', 'o...
# ASM                                                        []
# AND                                                        []
# AGO         [{'acronym': 'AU', 'name': 'African Union', 'o...
# AIA                                                        []
# ATA                                                        []
# ATG         [{'acronym': 'CARICOM', 'name': 'Caribbean Com...
# ARG         [{'acronym': 'USAN', 'name': 'Union of South A...
# ARM         [{'acronym': 'EEU', 'name': 'Eurasian Economic...
# ABW                                                        []
# AUS                                                        []
# AUT         [{'acronym': 'EU', 'name': 'European Union', '...
# AZE                                                        []
# BHS         [{'acronym': 'CARICOM', 'name': 'Caribbean Com...
# BHR         [{'acronym': 'AL', 'name': 'Arab League', 'oth...
# BGD         [{'acronym': 'SAARC', 'name': 'South Asian Ass...
# BRB         [{'acronym': 'CARICOM', 'name': 'Caribbean Com...
# BLR         [{'acronym': 'EEU', 'name': 'Eurasian Economic...
# BEL         [{'acronym': 'EU', 'name': 'European Union', '...
# BLZ         [{'acronym': 'CARICOM', 'name': 'Caribbean Com...
# BEN         [{'acronym': 'AU', 'name': 'African Union', 'o...
# BMU                                                        []
# BTN         [{'acronym': 'SAARC', 'name': 'South Asian Ass...
# BOL         [{'acronym': 'USAN', 'name': 'Union of South A...
# BES                                                        []
# BIH         [{'acronym': 'CEFTA', 'name': 'Central Europea...
# BWA         [{'acronym': 'AU', 'name': 'African Union', 'o...
# ...                                                       ...
# SYR         [{'acronym': 'AL', 'name': 'Arab League', 'oth...
# TWN                                                        []
# TJK                                                        []
# TZA         [{'acronym': 'AU', 'name': 'African Union', 'o...
# THA         [{'acronym': 'ASEAN', 'name': 'Association of ...
# TLS                                                        []
# TGO         [{'acronym': 'AU', 'name': 'African Union', 'o...
# TKL                                                        []
# TON                                                        []
# TTO         [{'acronym': 'CARICOM', 'name': 'Caribbean Com...
# TUN         [{'acronym': 'AU', 'name': 'African Union', 'o...
# TUR                                                        []
# TKM                                                        []
# TCA                                                        []
# TUV                                                        []
# UGA         [{'acronym': 'AU', 'name': 'African Union', 'o...
# UKR                                                        []
# ARE         [{'acronym': 'AL', 'name': 'Arab League', 'oth...
# GBR         [{'acronym': 'EU', 'name': 'European Union', '...
# USA         [{'acronym': 'NAFTA', 'name': 'North American ...
# URY         [{'acronym': 'USAN', 'name': 'Union of South A...
# UZB                                                        []
# VUT                                                        []
# VEN         [{'acronym': 'USAN', 'name': 'Union of South A...
# VNM         [{'acronym': 'ASEAN', 'name': 'Association of ...
# WLF                                                        []
# ESH         [{'acronym': 'AU', 'name': 'African Union', 'o...
# YEM         [{'acronym': 'AL', 'name': 'Arab League', 'oth...
# ZMB         [{'acronym': 'AU', 'name': 'African Union', 'o...
# ZWE         [{'acronym': 'AU', 'name': 'African Union', 'o...
#
#                             subregion  \
# alpha3Code
# AFG                     Southern Asia
# ALA                   Northern Europe
# ALB                   Southern Europe
# DZA                   Northern Africa
# ASM                         Polynesia
# AND                   Southern Europe
# AGO                     Middle Africa
# AIA                         Caribbean
# ATA
# ATG                         Caribbean
# ARG                     South America
# ARM                      Western Asia
# ABW                         Caribbean
# AUS         Australia and New Zealand
# AUT                    Western Europe
# AZE                      Western Asia
# BHS                         Caribbean
# BHR                      Western Asia
# BGD                     Southern Asia
# BRB                         Caribbean
# BLR                    Eastern Europe
# BEL                    Western Europe
# BLZ                   Central America
# BEN                    Western Africa
# BMU                  Northern America
# BTN                     Southern Asia
# BOL                     South America
# BES                         Caribbean
# BIH                   Southern Europe
# BWA                   Southern Africa
# ...                               ...
# SYR                      Western Asia
# TWN                      Eastern Asia
# TJK                      Central Asia
# TZA                    Eastern Africa
# THA                South-Eastern Asia
# TLS                South-Eastern Asia
# TGO                    Western Africa
# TKL                         Polynesia
# TON                         Polynesia
# TTO                         Caribbean
# TUN                   Northern Africa
# TUR                      Western Asia
# TKM                      Central Asia
# TCA                         Caribbean
# TUV                         Polynesia
# UGA                    Eastern Africa
# UKR                    Eastern Europe
# ARE                      Western Asia
# GBR                   Northern Europe
# USA                  Northern America
# URY                     South America
# UZB                      Central Asia
# VUT                         Melanesia
# VEN                     South America
# VNM                South-Eastern Asia
# WLF                         Polynesia
# ESH                   Northern Africa
# YEM                      Western Asia
# ZMB                    Eastern Africa
# ZWE                    Eastern Africa
#
#                                                     timezones topLevelDomain  \
# alpha3Code
# AFG                                               [UTC+04:30]          [.af]
# ALA                                               [UTC+02:00]          [.ax]
# ALB                                               [UTC+01:00]          [.al]
# DZA                                               [UTC+01:00]          [.dz]
# ASM                                               [UTC-11:00]          [.as]
# AND                                               [UTC+01:00]          [.ad]
# AGO                                               [UTC+01:00]          [.ao]
# AIA                                               [UTC-04:00]          [.ai]
# ATA         [UTC-03:00, UTC+03:00, UTC+05:00, UTC+06:00, U...          [.aq]
# ATG                                               [UTC-04:00]          [.ag]
# ARG                                               [UTC-03:00]          [.ar]
# ARM                                               [UTC+04:00]          [.am]
# ABW                                               [UTC-04:00]          [.aw]
# AUS         [UTC+05:00, UTC+06:30, UTC+07:00, UTC+08:00, U...          [.au]
# AUT                                               [UTC+01:00]          [.at]
# AZE                                               [UTC+04:00]          [.az]
# BHS                                               [UTC-05:00]          [.bs]
# BHR                                               [UTC+03:00]          [.bh]
# BGD                                               [UTC+06:00]          [.bd]
# BRB                                               [UTC-04:00]          [.bb]
# BLR                                               [UTC+03:00]          [.by]
# BEL                                               [UTC+01:00]          [.be]
# BLZ                                               [UTC-06:00]          [.bz]
# BEN                                               [UTC+01:00]          [.bj]
# BMU                                               [UTC-04:00]          [.bm]
# BTN                                               [UTC+06:00]          [.bt]
# BOL                                               [UTC-04:00]          [.bo]
# BES                                               [UTC-04:00]     [.an, .nl]
# BIH                                               [UTC+01:00]          [.ba]
# BWA                                               [UTC+02:00]          [.bw]
# ...                                                       ...            ...
# SYR                                               [UTC+02:00]          [.sy]
# TWN                                               [UTC+08:00]          [.tw]
# TJK                                               [UTC+05:00]          [.tj]
# TZA                                               [UTC+03:00]          [.tz]
# THA                                               [UTC+07:00]          [.th]
# TLS                                               [UTC+09:00]          [.tl]
# TGO                                                     [UTC]          [.tg]
# TKL                                               [UTC+13:00]          [.tk]
# TON                                               [UTC+13:00]          [.to]
# TTO                                               [UTC-04:00]          [.tt]
# TUN                                               [UTC+01:00]          [.tn]
# TUR                                               [UTC+03:00]          [.tr]
# TKM                                               [UTC+05:00]          [.tm]
# TCA                                               [UTC-04:00]          [.tc]
# TUV                                               [UTC+12:00]          [.tv]
# UGA                                               [UTC+03:00]          [.ug]
# UKR                                               [UTC+02:00]          [.ua]
# ARE                                                  [UTC+04]          [.ae]
# GBR         [UTC-08:00, UTC-05:00, UTC-04:00, UTC-03:00, U...          [.uk]
# USA         [UTC-12:00, UTC-11:00, UTC-10:00, UTC-09:00, U...          [.us]
# URY                                               [UTC-03:00]          [.uy]
# UZB                                               [UTC+05:00]          [.uz]
# VUT                                               [UTC+11:00]          [.vu]
# VEN                                               [UTC-04:00]          [.ve]
# VNM                                               [UTC+07:00]          [.vn]
# WLF                                               [UTC+12:00]          [.wf]
# ESH                                               [UTC+00:00]          [.eh]
# YEM                                               [UTC+03:00]          [.ye]
# ZMB                                               [UTC+02:00]          [.zm]
# ZWE                                               [UTC+02:00]          [.zw]
#
#                                                  translations  \
# alpha3Code
# AFG         {'de': 'Afghanistan', 'es': 'Afganistán', 'fr'...
# ALA         {'de': 'Åland', 'es': 'Alandia', 'fr': 'Åland'...
# ALB         {'de': 'Albanien', 'es': 'Albania', 'fr': 'Alb...
# DZA         {'de': 'Algerien', 'es': 'Argelia', 'fr': 'Alg...
# ASM         {'de': 'Amerikanisch-Samoa', 'es': 'Samoa Amer...
# AND         {'de': 'Andorra', 'es': 'Andorra', 'fr': 'Ando...
# AGO         {'de': 'Angola', 'es': 'Angola', 'fr': 'Angola...
# AIA         {'de': 'Anguilla', 'es': 'Anguilla', 'fr': 'An...
# ATA         {'de': 'Antarktika', 'es': 'Antártida', 'fr': ...
# ATG         {'de': 'Antigua und Barbuda', 'es': 'Antigua y...
# ARG         {'de': 'Argentinien', 'es': 'Argentina', 'fr':...
# ARM         {'de': 'Armenien', 'es': 'Armenia', 'fr': 'Arm...
# ABW         {'de': 'Aruba', 'es': 'Aruba', 'fr': 'Aruba', ...
# AUS         {'de': 'Australien', 'es': 'Australia', 'fr': ...
# AUT         {'de': 'Österreich', 'es': 'Austria', 'fr': 'A...
# AZE         {'de': 'Aserbaidschan', 'es': 'Azerbaiyán', 'f...
# BHS         {'de': 'Bahamas', 'es': 'Bahamas', 'fr': 'Baha...
# BHR         {'de': 'Bahrain', 'es': 'Bahrein', 'fr': 'Bahr...
# BGD         {'de': 'Bangladesch', 'es': 'Bangladesh', 'fr'...
# BRB         {'de': 'Barbados', 'es': 'Barbados', 'fr': 'Ba...
# BLR         {'de': 'Weißrussland', 'es': 'Bielorrusia', 'f...
# BEL         {'de': 'Belgien', 'es': 'Bélgica', 'fr': 'Belg...
# BLZ         {'de': 'Belize', 'es': 'Belice', 'fr': 'Belize...
# BEN         {'de': 'Benin', 'es': 'Benín', 'fr': 'Bénin', ...
# BMU         {'de': 'Bermuda', 'es': 'Bermudas', 'fr': 'Ber...
# BTN         {'de': 'Bhutan', 'es': 'Bután', 'fr': 'Bhoutan...
# BOL         {'de': 'Bolivien', 'es': 'Bolivia', 'fr': 'Bol...
# BES         {'de': 'Bonaire, Sint Eustatius und Saba', 'es...
# BIH         {'de': 'Bosnien und Herzegowina', 'es': 'Bosni...
# BWA         {'de': 'Botswana', 'es': 'Botswana', 'fr': 'Bo...
# ...                                                       ...
# SYR         {'de': 'Syrien', 'es': 'Siria', 'fr': 'Syrie',...
# TWN         {'de': 'Taiwan', 'es': 'Taiwán', 'fr': 'Taïwan...
# TJK         {'de': 'Tadschikistan', 'es': 'Tayikistán', 'f...
# TZA         {'de': 'Tansania', 'es': 'Tanzania', 'fr': 'Ta...
# THA         {'de': 'Thailand', 'es': 'Tailandia', 'fr': 'T...
# TLS         {'de': 'Timor-Leste', 'es': 'Timor Oriental', ...
# TGO         {'de': 'Togo', 'es': 'Togo', 'fr': 'Togo', 'ja...
# TKL         {'de': 'Tokelau', 'es': 'Islas Tokelau', 'fr':...
# TON         {'de': 'Tonga', 'es': 'Tonga', 'fr': 'Tonga', ...
# TTO         {'de': 'Trinidad und Tobago', 'es': 'Trinidad ...
# TUN         {'de': 'Tunesien', 'es': 'Túnez', 'fr': 'Tunis...
# TUR         {'de': 'Türkei', 'es': 'Turquía', 'fr': 'Turqu...
# TKM         {'de': 'Turkmenistan', 'es': 'Turkmenistán', '...
# TCA         {'de': 'Turks- und Caicosinseln', 'es': 'Islas...
# TUV         {'de': 'Tuvalu', 'es': 'Tuvalu', 'fr': 'Tuvalu...
# UGA         {'de': 'Uganda', 'es': 'Uganda', 'fr': 'Uganda...
# UKR         {'de': 'Ukraine', 'es': 'Ucrania', 'fr': 'Ukra...
# ARE         {'de': 'Vereinigte Arabische Emirate', 'es': '...
# GBR         {'de': 'Vereinigtes Königreich', 'es': 'Reino ...
# USA         {'de': 'Vereinigte Staaten von Amerika', 'es':...
# URY         {'de': 'Uruguay', 'es': 'Uruguay', 'fr': 'Urug...
# UZB         {'de': 'Usbekistan', 'es': 'Uzbekistán', 'fr':...
# VUT         {'de': 'Vanuatu', 'es': 'Vanuatu', 'fr': 'Vanu...
# VEN         {'de': 'Venezuela', 'es': 'Venezuela', 'fr': '...
# VNM         {'de': 'Vietnam', 'es': 'Vietnam', 'fr': 'Viêt...
# WLF         {'de': 'Wallis und Futuna', 'es': 'Wallis y Fu...
# ESH         {'de': 'Westsahara', 'es': 'Sahara Occidental'...
# YEM         {'de': 'Jemen', 'es': 'Yemen', 'fr': 'Yémen', ...
# ZMB         {'de': 'Sambia', 'es': 'Zambia', 'fr': 'Zambie...
# ZWE         {'de': 'Simbabwe', 'es': 'Zimbabue', 'fr': 'Zi...
#
#                                  strborders
# alpha3Code
# AFG                 IRN,PAK,TKM,UZB,TJK,CHN
# ALA
# ALB                         MNE,GRC,MKD,KOS
# DZA             TUN,LBY,NER,ESH,MRT,MLI,MAR
# ASM
# AND                                 FRA,ESP
# AGO                         COG,COD,ZMB,NAM
# AIA
# ATA
# ATG
# ARG                     BOL,BRA,CHL,PRY,URY
# ARM                         AZE,GEO,IRN,TUR
# ABW
# AUS
# AUT         CZE,DEU,HUN,ITA,LIE,SVK,SVN,CHE
# AZE                     ARM,GEO,IRN,RUS,TUR
# BHS
# BHR
# BGD                                 MMR,IND
# BRB
# BLR                     LVA,LTU,POL,RUS,UKR
# BEL                         FRA,DEU,LUX,NLD
# BLZ                                 GTM,MEX
# BEN                         BFA,NER,NGA,TGO
# BMU
# BTN                                 CHN,IND
# BOL                     ARG,BRA,CHL,PRY,PER
# BES
# BIH                             HRV,MNE,SRB
# BWA                         NAM,ZAF,ZMB,ZWE
# ...                                     ...
# SYR                     IRQ,ISR,JOR,LBN,TUR
# TWN
# TJK                         AFG,CHN,KGZ,UZB
# TZA         BDI,COD,KEN,MWI,MOZ,RWA,UGA,ZMB
# THA                         MMR,KHM,LAO,MYS
# TLS                                     IDN
# TGO                             BEN,BFA,GHA
# TKL
# TON
# TTO
# TUN                                 DZA,LBY
# TUR         ARM,AZE,BGR,GEO,GRC,IRN,IRQ,SYR
# TKM                         AFG,IRN,KAZ,UZB
# TCA
# TUV
# UGA                     COD,KEN,RWA,SSD,TZA
# UKR             BLR,HUN,MDA,POL,ROU,RUS,SVK
# ARE                                 OMN,SAU
# GBR                                     IRL
# USA                                 CAN,MEX
# URY                                 ARG,BRA
# UZB                     AFG,KAZ,KGZ,TJK,TKM
# VUT
# VEN                             BRA,COL,GUY
# VNM                             KHM,CHN,LAO
# WLF
# ESH                             DZA,MRT,MAR
# YEM                                 OMN,SAU
# ZMB         AGO,BWA,COD,MWI,MOZ,NAM,TZA,ZWE
# ZWE                         BWA,MOZ,ZAF,ZMB
#
# [250 rows x 24 columns]

# %%
sales
# Out:
#   Month  Book City  Units
# 0   JAN  B100  VZG   10.0
# 1   FEB  B100  VZG    4.0
# 2   MAR  B100  VZG   13.0
# 3   JAN  B100  HYD   30.0
# 4   FEB  B100  HYD   40.0
# 5   MAR  B100  HYD   10.0
# 6   JAN  B200  VZG   14.0
# 7   FEB  B200  HYD    NaN
# 8   MAR  B200  NaN    4.0

# %%
sales.sort_values(['Month'])
# Out:
#   Month  Book City  Units
# 1   FEB  B100  VZG    4.0
# 4   FEB  B100  HYD   40.0
# 7   FEB  B200  HYD    NaN
# 0   JAN  B100  VZG   10.0
# 3   JAN  B100  HYD   30.0
# 6   JAN  B200  VZG   14.0
# 2   MAR  B100  VZG   13.0
# 5   MAR  B100  HYD   10.0
# 8   MAR  B200  NaN    4.0

# %%
sales.sort_index()
# Out:
#   Month  Book City  Units
# 0   JAN  B100  VZG   10.0
# 1   FEB  B100  VZG    4.0
# 2   MAR  B100  VZG   13.0
# 3   JAN  B100  HYD   30.0
# 4   FEB  B100  HYD   40.0
# 5   MAR  B100  HYD   10.0
# 6   JAN  B200  VZG   14.0
# 7   FEB  B200  HYD    NaN
# 8   MAR  B200  NaN    4.0

# %%
sdf = sales.copy()

# %%
sdf.drop([4],axis=0, inplace=True)

# %%
sdf = sdf.reset_index()

# %%
sdf.columns
# Out:
# Index(['index', 'Month', 'Book', 'City', 'Units'], dtype='object')

# %%
sdf.drop(['index'], axis=1, inplace=True)

# %%
sdf
# Out:
#   Month  Book City  Units
# 0   JAN  B100  VZG   10.0
# 1   FEB  B100  VZG    4.0
# 2   MAR  B100  VZG   13.0
# 3   JAN  B100  HYD   30.0
# 4   MAR  B100  HYD   10.0
# 5   JAN  B200  VZG   14.0
# 6   FEB  B200  HYD    NaN
# 7   MAR  B200  NaN    4.0

# %%
sales.sort_values(['Month','Book','City'])
# Out:
#   Month  Book City  Units
# 4   FEB  B100  HYD   40.0
# 1   FEB  B100  VZG    4.0
# 7   FEB  B200  HYD    NaN
# 3   JAN  B100  HYD   30.0
# 0   JAN  B100  VZG   10.0
# 6   JAN  B200  VZG   14.0
# 5   MAR  B100  HYD   10.0
# 2   MAR  B100  VZG   13.0
# 8   MAR  B200  NaN    4.0

# %%
cdf['region'].value_counts()
# Out:
# Africa      60
# Americas    57
# Europe      53
# Asia        50
# Oceania     27
#              2
# Polar        1
# Name: region, dtype: int64

# %%
sales['Book'].value_counts()
# Out:
# B100    6
# B200    3
# Name: Book, dtype: int64

# %%
sales
# Out:
#   Month  Book City  Units
# 0   JAN  B100  VZG   10.0
# 1   FEB  B100  VZG    4.0
# 2   MAR  B100  VZG   13.0
# 3   JAN  B100  HYD   30.0
# 4   FEB  B100  HYD   40.0
# 5   MAR  B100  HYD   10.0
# 6   JAN  B200  VZG   14.0
# 7   FEB  B200  HYD    NaN
# 8   MAR  B200  NaN    4.0

# %%
cdf['region'].nunique()
# Out:
# 7

# %%
sales.isna().any(axis=1)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8     True
# dtype: bool

# %%
sales.loc[ sales.isna().any(axis=1), :]
# Out:
#   Month  Book City  Units
# 7   FEB  B200  HYD    NaN
# 8   MAR  B200  NaN    4.0

# %%
sales['Book'].isna().any()
# Out:
# False

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
# Month    9 non-null object
# Book     9 non-null object
# City     8 non-null object
# Units    8 non-null float64
# dtypes: float64(1), object(3)
# memory usage: 368.0+ bytes

# %%
sales.loc[ :,sales.notna().all()]
# Out:
#   Month  Book
# 0   JAN  B100
# 1   FEB  B100
# 2   MAR  B100
# 3   JAN  B100
# 4   FEB  B100
# 5   MAR  B100
# 6   JAN  B200
# 7   FEB  B200
# 8   MAR  B200

# %%
sales.dropna()
# Out:
#   Month  Book City  Units
# 0   JAN  B100  VZG   10.0
# 1   FEB  B100  VZG    4.0
# 2   MAR  B100  VZG   13.0
# 3   JAN  B100  HYD   30.0
# 4   FEB  B100  HYD   40.0
# 5   MAR  B100  HYD   10.0
# 6   JAN  B200  VZG   14.0

# %%
sales.fillna(0)
# Out:
#   Month  Book City  Units
# 0   JAN  B100  VZG   10.0
# 1   FEB  B100  VZG    4.0
# 2   MAR  B100  VZG   13.0
# 3   JAN  B100  HYD   30.0
# 4   FEB  B100  HYD   40.0
# 5   MAR  B100  HYD   10.0
# 6   JAN  B200  VZG   14.0
# 7   FEB  B200  HYD    0.0
# 8   MAR  B200    0    4.0
