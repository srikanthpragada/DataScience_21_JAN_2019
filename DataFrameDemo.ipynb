# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.arange(9).reshape(3,3))

# %%
df
# Out:
#    0  1  2
# 0  0  1  2
# 1  3  4  5
# 2  6  7  8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
# 0    3 non-null int32
# 1    3 non-null int32
# 2    3 non-null int32
# dtypes: int32(3)
# memory usage: 116.0 bytes

# %%
df = pd.DataFrame(np.arange(9).reshape(3,3), columns=list("ABC"))

# %%
df
# Out:
#    A  B  C
# 0  0  1  2
# 1  3  4  5
# 2  6  7  8

# %%
df['A']
# Out:
# 0    0
# 1    3
# 2    6
# Name: A, dtype: int32

# %%
df[['A','C']]
# Out:
#    A  C
# 0  0  2
# 1  3  5
# 2  6  8

# %%
df['A'][1]
# Out:
# 3

# %%
df.A  # Not recom.
# Out:
# 0    0
# 1    3
# 2    6
# Name: A, dtype: int32

# %%
df[:2]['A']
# Out:
# 0    0
# 1    3
# Name: A, dtype: int32

# %%
df[:1][:]
# Out:
#    A  B  C
# 0  0  1  2

# %%
sales = pd.read_csv('sales.txt')

# %%
sales
# Out:
#   Month  Book City  Units
# 0   JAN  B100  VZG   10.0
# 1   FEB  B100  VZG    4.0
# 2   MAR  B100  VZG   13.0
# 3   JAN  B100  HYD   30.0
# 4   FEB  B100  HYD   40.0
# 5   MAR  B100  HYD   10.0
# 6   JAN  B200  VZG   14.0
# 7   FEB  B200  HYD    NaN
# 8   MAR  B200  NaN    4.0

# %%
sales.describe()
# Out:
#           Units
# count   8.00000
# mean   15.62500
# std    12.78322
# min     4.00000
# 25%     8.50000
# 50%    11.50000
# 75%    18.00000
# max    40.00000

# %%
sales.describe(include='all')
# Out:
#        Month  Book City     Units
# count      9     9    8   8.00000
# unique     3     2    2       NaN
# top      JAN  B100  VZG       NaN
# freq       3     6    4       NaN
# mean     NaN   NaN  NaN  15.62500
# std      NaN   NaN  NaN  12.78322
# min      NaN   NaN  NaN   4.00000
# 25%      NaN   NaN  NaN   8.50000
# 50%      NaN   NaN  NaN  11.50000
# 75%      NaN   NaN  NaN  18.00000
# max      NaN   NaN  NaN  40.00000

# %%
sales
# Out:
#   Month  Book City  Units
# 0   JAN  B100  VZG   10.0
# 1   FEB  B100  VZG    4.0
# 2   MAR  B100  VZG   13.0
# 3   JAN  B100  HYD   30.0
# 4   FEB  B100  HYD   40.0
# 5   MAR  B100  HYD   10.0
# 6   JAN  B200  VZG   14.0
# 7   FEB  B200  HYD    NaN
# 8   MAR  B200  NaN    4.0

# %%
sales
# Out:
#   Month  Book City  Units
# 0   JAN  B100  VZG   10.0
# 1   FEB  B100  VZG    4.0
# 2   MAR  B100  VZG   13.0
# 3   JAN  B100  HYD   30.0
# 4   FEB  B100  HYD   40.0
# 5   MAR  B100  HYD   10.0
# 6   JAN  B200  VZG   14.0
# 7   FEB  B200  HYD    NaN
# 8   MAR  B200  NaN    4.0

# %%
sales.loc[0,'Units']
# Out:
# 10.0

# %%
sales.head()
# Out:
#   Month  Book City  Units
# 0   JAN  B100  VZG   10.0
# 1   FEB  B100  VZG    4.0
# 2   MAR  B100  VZG   13.0
# 3   JAN  B100  HYD   30.0
# 4   FEB  B100  HYD   40.0

# %%
sales.loc[ sales.City == 'VZG' , ['Book','Units'] ]
# Out:
#    Book  Units
# 0  B100   10.0
# 1  B100    4.0
# 2  B100   13.0
# 6  B200   14.0

# %%
units = sales.loc[ : , 'Units']

# %%
type(units)
# Out:
# pandas.core.series.Series

# %%
det = sales.loc[ : , ['Book','Units']]

# %%
type(det)
# Out:
# pandas.core.frame.DataFrame

# %%
sales.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
sales.iloc[0,:]
# Out:
# Month     JAN
# Book     B100
# City      VZG
# Units      10
# Name: 0, dtype: object

# %% [markdown]
# ## Read data about countries

# %%
import requests

# %%
resp = requests.get("https://restcountries.eu/rest/v2/all")

# %%
cdf = pd.DataFrame(resp.json())

# %%
cdf.head()
# Out:
#   alpha2Code alpha3Code                                       altSpellings  \
# 0         AF        AFG                                   [AF, Afġānistān]
# 1         AX        ALA                    [AX, Aaland, Aland, Ahvenanmaa]
# 2         AL        ALB                [AL, Shqipëri, Shqipëria, Shqipnia]
# 3         DZ        DZA                              [DZ, Dzayer, Algérie]
# 4         AS        ASM  [AS, Amerika Sāmoa, Amelika Sāmoa, Sāmoa Amelika]
#
#         area                              borders callingCodes    capital  \
# 0   652230.0       [IRN, PAK, TKM, UZB, TJK, CHN]         [93]      Kabul
# 1     1580.0                                   []        [358]  Mariehamn
# 2    28748.0                 [MNE, GRC, MKD, KOS]        [355]     Tirana
# 3  2381741.0  [TUN, LBY, NER, ESH, MRT, MLI, MAR]        [213]    Algiers
# 4      199.0                                   []       [1684]  Pago Pago
#
#   cioc                                         currencies          demonym  \
# 0  AFG  [{'code': 'AFN', 'name': 'Afghan afghani', 'sy...           Afghan
# 1        [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]         Ålandish
# 2  ALB  [{'code': 'ALL', 'name': 'Albanian lek', 'symb...         Albanian
# 3  ALG  [{'code': 'DZD', 'name': 'Algerian dinar', 'sy...         Algerian
# 4  ASA  [{'code': 'USD', 'name': 'United State Dollar'...  American Samoan
#
#                          ...                                    name  \
# 0                        ...                             Afghanistan
# 1                        ...                           Åland Islands
# 2                        ...                                 Albania
# 3                        ...                                 Algeria
# 4                        ...                          American Samoa
#
#        nativeName numericCode population   region  \
# 0       افغانستان         004   27657145     Asia
# 1           Åland         248      28875   Europe
# 2       Shqipëria         008    2886026   Europe
# 3         الجزائر         012   40400000   Africa
# 4  American Samoa         016      57100  Oceania
#
#                                        regionalBlocs        subregion  \
# 0  [{'acronym': 'SAARC', 'name': 'South Asian Ass...    Southern Asia
# 1  [{'acronym': 'EU', 'name': 'European Union', '...  Northern Europe
# 2  [{'acronym': 'CEFTA', 'name': 'Central Europea...  Southern Europe
# 3  [{'acronym': 'AU', 'name': 'African Union', 'o...  Northern Africa
# 4                                                 []        Polynesia
#
#      timezones topLevelDomain  \
# 0  [UTC+04:30]          [.af]
# 1  [UTC+02:00]          [.ax]
# 2  [UTC+01:00]          [.al]
# 3  [UTC+01:00]          [.dz]
# 4  [UTC-11:00]          [.as]
#
#                                         translations
# 0  {'de': 'Afghanistan', 'es': 'Afganistán', 'fr'...
# 1  {'de': 'Åland', 'es': 'Alandia', 'fr': 'Åland'...
# 2  {'de': 'Albanien', 'es': 'Albania', 'fr': 'Alb...
# 3  {'de': 'Algerien', 'es': 'Argelia', 'fr': 'Alg...
# 4  {'de': 'Amerikanisch-Samoa', 'es': 'Samoa Amer...
#
# [5 rows x 24 columns]

# %%
cdf.describe()
# Out:
#                area        gini    population
# count  2.400000e+02  153.000000  2.500000e+02
# mean   6.262107e+05   40.177124  2.939655e+07
# std    1.950028e+06    9.265119  1.244578e+08
# min    4.400000e-01   24.000000  0.000000e+00
# 25%    1.533250e+03   33.700000  2.029030e+05
# 50%    7.100650e+04   38.600000  4.648734e+06
# 75%    4.146432e+05   46.200000  1.803955e+07
# max    1.712444e+07   65.800000  1.377422e+09

# %%
cdf['population']
# Out:
# 0       27657145
# 1          28875
# 2        2886026
# 3       40400000
# 4          57100
# 5          78014
# 6       25868000
# 7          13452
# 8           1000
# 9          86295
# 10      43590400
# 11       2994400
# 12        107394
# 13      24117360
# 14       8725931
# 15       9730500
# 16        378040
# 17       1404900
# 18     161006790
# 19        285000
# 20       9498700
# 21      11319511
# 22        370300
# 23      10653654
# 24         61954
# 25        775620
# 26      10985059
# 27         17408
# 28       3531159
# 29       2141206
#          ...
# 220     18564000
# 221     23503349
# 222      8593600
# 223     55155000
# 224     65327652
# 225      1167242
# 226      7143000
# 227         1411
# 228       103252
# 229      1349667
# 230     11154400
# 231     78741053
# 232      4751120
# 233        31458
# 234        10640
# 235     33860700
# 236     42692393
# 237      9856000
# 238     65110000
# 239    323947000
# 240      3480222
# 241     31576400
# 242       277500
# 243     31028700
# 244     92700000
# 245        11750
# 246       510713
# 247     27478000
# 248     15933883
# 249     14240168
# Name: population, Length: 250, dtype: int64

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 24 columns):
# alpha2Code        250 non-null object
# alpha3Code        250 non-null object
# altSpellings      250 non-null object
# area              240 non-null float64
# borders           250 non-null object
# callingCodes      250 non-null object
# capital           250 non-null object
# cioc              247 non-null object
# currencies        250 non-null object
# demonym           250 non-null object
# flag              250 non-null object
# gini              153 non-null float64
# languages         250 non-null object
# latlng            250 non-null object
# name              250 non-null object
# nativeName        250 non-null object
# numericCode       249 non-null object
# population        250 non-null int64
# region            250 non-null object
# regionalBlocs     250 non-null object
# subregion         250 non-null object
# timezones         250 non-null object
# topLevelDomain    250 non-null object
# translations      250 non-null object
# dtypes: float64(2), int64(1), object(21)
# memory usage: 47.0+ KB

# %% [markdown]
# ## 11-FEB

# %%
# cdf[ ['alpha3Code','name','capital','population','area']].head()
cdf.loc[:5, ['alpha3Code','name','capital','population','area']]
# Out:
#   alpha3Code            name           capital  population       area
# 0        AFG     Afghanistan             Kabul    27657145   652230.0
# 1        ALA   Åland Islands         Mariehamn       28875     1580.0
# 2        ALB         Albania            Tirana     2886026    28748.0
# 3        DZA         Algeria           Algiers    40400000  2381741.0
# 4        ASM  American Samoa         Pago Pago       57100      199.0
# 5        AND         Andorra  Andorra la Vella       78014      468.0

# %%
c = cdf['currencies'].apply()

# %%
def get_codes(lst):
    return lst[0]['code']

# %%
c = cdf['currencies'].apply(get_codes).head()

# %%
c
# Out:
# 0    AFN
# 1    EUR
# 2    ALL
# 3    DZD
# 4    USD
# Name: currencies, dtype: object

# %%
def get_all_codes(lst):
    codes = []
    for c in lst:
        if 'code' in c and c['code'] is not None:
           codes.append( c['code'])
        
    return ",".join(codes)

# %%
cdf['currencies'].apply(get_all_codes).head(25)
# Out:
# 0         AFN
# 1         EUR
# 2         ALL
# 3         DZD
# 4         USD
# 5         EUR
# 6         AOA
# 7         XCD
# 8     AUD,GBP
# 9         XCD
# 10        ARS
# 11        AMD
# 12        AWG
# 13        AUD
# 14        EUR
# 15        AZN
# 16        BSD
# 17        BHD
# 18        BDT
# 19        BBD
# 20    BYN,BYR
# 21        EUR
# 22        BZD
# 23        XOF
# 24        BMD
# Name: currencies, dtype: object

# %%
cdf.loc[8,'currencies']
# Out:
# [{'code': 'AUD', 'name': 'Australian dollar', 'symbol': '$'},
#  {'code': 'GBP', 'name': 'British pound', 'symbol': '£'}]

# %%
cdf.at[8,'currencies']
# Out:
# [{'code': 'AUD', 'name': 'Australian dollar', 'symbol': '$'},
#  {'code': 'GBP', 'name': 'British pound', 'symbol': '£'}]

# %%
cor = 10000000

# %%
cdf[cdf['borders'].str]
# Out:
#     alpha2Code alpha3Code                                       altSpellings  \
# 1           AX        ALA                    [AX, Aaland, Aland, Ahvenanmaa]
# 4           AS        ASM  [AS, Amerika Sāmoa, Amelika Sāmoa, Sāmoa Amelika]
# 7           AI        AIA                                               [AI]
# 8           AQ        ATA                                                 []
# 9           AG        ATG                                               [AG]
# 12          AW        ABW                                               [AW]
# 13          AU        AUS                                               [AU]
# 16          BS        BHS                  [BS, Commonwealth of the Bahamas]
# 17          BH        BHR      [BH, Kingdom of Bahrain, Mamlakat al-Baḥrayn]
# 19          BB        BRB                                               [BB]
# 24          BM        BMU  [BM, The Islands of Bermuda, The Bermudas, Som...
# 27          BQ        BES                                      [BQ, Boneiru]
# 30          BV        BVT                        [BV, Bouvetøya, Bouvet-øya]
# 32          IO        IOT                                               [IO]
# 33          UM        UMI                                               [UM]
# 34          VG        VGB                                               [VG]
# 35          VI        VIR  [VI, USVI, American Virgin Islands, U.S. Virgi...
# 43          CV        CPV  [CV, Republic of Cabo Verde, República de Cabo...
# 44          KY        CYM                                               [KY]
# 49          CX        CXR                [CX, Territory of Christmas Island]
# 50          CC        CCK  [CC, Territory of the Cocos (Keeling) Islands,...
# 52          KM        COM  [KM, Union of the Comoros, Union des Comores, ...
# 55          CK        COK                                 [CK, Kūki 'Āirani]
# 58          CU        CUB          [CU, Republic of Cuba, República de Cuba]
# 59          CW        CUW  [CW, Curacao, Kòrsou, Country of Curaçao, Land...
# 64          DM        DMA  [DM, Dominique, Wai‘tu kubuli, Commonwealth of...
# 73          FK        FLK                               [FK, Islas Malvinas]
# 74          FO        FRO                            [FO, Føroyar, Færøerne]
# 75          FJ        FJI  [FJ, Viti, Republic of Fiji, Matanitu ko Viti,...
# 79          PF        PYF  [PF, Polynésie française, French Polynesia, Pō...
# ..         ...        ...                                                ...
# 159         NZ        NZL                                     [NZ, Aotearoa]
# 163         NU        NIU                                               [NU]
# 164         NF        NFK  [NF, Territory of Norfolk Island, Teratri of N...
# 166         MP        MNP  [MP, Commonwealth of the Northern Mariana Isla...
# 170         PW        PLW          [PW, Republic of Palau, Beluu er a Belau]
# 176         PH        PHL  [PH, Republic of the Philippines, Repúblika ng...
# 177         PN        PCN    [PN, Pitcairn Henderson Ducie and Oeno Islands]
# 180         PR        PRI  [PR, Commonwealth of Puerto Rico, Estado Libre...
# 183         RE        REU                                      [RE, Reunion]
# 187         BL        BLM  [BL, St. Barthelemy, Collectivity of Saint Bar...
# 188         SH        SHN                                               [SH]
# 189         KN        KNA    [KN, Federation of Saint Christopher and Nevis]
# 190         LC        LCA                                               [LC]
# 192         PM        SPM  [PM, Collectivité territoriale de Saint-Pierre...
# 193         VC        VCT                                               [VC]
# 194         WS        WSM  [WS, Independent State of Samoa, Malo Saʻoloto...
# 196         ST        STP  [ST, Democratic Republic of São Tomé and Prínc...
# 200         SC        SYC  [SC, Republic of Seychelles, Repiblik Sesel, R...
# 202         SG        SGP        [SG, Singapura, Republik Singapura, 新加坡共和国]
# 206         SB        SLB                                               [SB]
# 209         GS        SGS  [GS, South Georgia and the South Sandwich Isla...
# 216         SJ        SJM               [SJ, Svalbard and Jan Mayen Islands]
# 221         TW        TWN  [TW, Táiwān, Republic of China, 中華民國, Zhōnghuá...
# 227         TK        TKL                                               [TK]
# 228         TO        TON                                               [TO]
# 229         TT        TTO              [TT, Republic of Trinidad and Tobago]
# 233         TC        TCA                                               [TC]
# 234         TV        TUV                                               [TV]
# 242         VU        VUT  [VU, Republic of Vanuatu, Ripablik blong Vanua...
# 245         WF        WLF  [WF, Territory of the Wallis and Futuna Island...
#
#             area borders  callingCodes            capital  cioc  \
# 1        1580.00      []         [358]          Mariehamn
# 4         199.00      []        [1684]          Pago Pago   ASA
# 7          91.00      []        [1264]         The Valley
# 8    14000000.00      []         [672]
# 9         442.00      []        [1268]       Saint John's   ANT
# 12        180.00      []         [297]         Oranjestad   ARU
# 13    7692024.00      []          [61]           Canberra   AUS
# 16      13943.00      []        [1242]             Nassau   BAH
# 17        765.00      []         [973]             Manama   BRN
# 19        430.00      []        [1246]         Bridgetown   BAR
# 24         54.00      []        [1441]           Hamilton   BER
# 27        294.00      []        [5997]         Kralendijk  None
# 30         49.00      []            []
# 32         60.00      []         [246]       Diego Garcia
# 33           NaN      []            []
# 34        151.00      []        [1284]          Road Town   IVB
# 35        346.36      []       [1 340]   Charlotte Amalie   ISV
# 43       4033.00      []         [238]              Praia   CPV
# 44        264.00      []        [1345]        George Town   CAY
# 49        135.00      []          [61]   Flying Fish Cove
# 50         14.00      []          [61]        West Island
# 52       1862.00      []         [269]             Moroni   COM
# 55        236.00      []         [682]             Avarua   COK
# 58     109884.00      []          [53]             Havana   CUB
# 59        444.00      []         [599]         Willemstad
# 64        751.00      []        [1767]             Roseau   DMA
# 73      12173.00      []         [500]            Stanley
# 74       1393.00      []         [298]           Tórshavn
# 75      18272.00      []         [679]               Suva   FIJ
# 79       4167.00      []         [689]            Papeetē
# ..           ...     ...           ...                ...   ...
# 159    270467.00      []          [64]         Wellington   NZL
# 163       260.00      []         [683]              Alofi
# 164        36.00      []         [672]           Kingston
# 166       464.00      []        [1670]             Saipan
# 170       459.00      []         [680]          Ngerulmud   PLW
# 176    342353.00      []          [63]             Manila   PHI
# 177        47.00      []          [64]          Adamstown
# 180      8870.00      []  [1787, 1939]           San Juan   PUR
# 183          NaN      []         [262]        Saint-Denis
# 187        21.00      []         [590]           Gustavia
# 188          NaN      []         [290]          Jamestown  None
# 189       261.00      []        [1869]         Basseterre   SKN
# 190       616.00      []        [1758]           Castries   LCA
# 192       242.00      []         [508]       Saint-Pierre
# 193       389.00      []        [1784]          Kingstown   VIN
# 194      2842.00      []         [685]               Apia   SAM
# 196       964.00      []         [239]           São Tomé   STP
# 200       452.00      []         [248]           Victoria   SEY
# 202       710.00      []          [65]          Singapore   SIN
# 206     28896.00      []         [677]            Honiara   SOL
# 209          NaN      []         [500]  King Edward Point
# 216          NaN      []        [4779]       Longyearbyen
# 221     36193.00      []         [886]             Taipei   TPE
# 227        12.00      []         [690]            Fakaofo
# 228       747.00      []         [676]         Nuku'alofa   TGA
# 229      5130.00      []        [1868]      Port of Spain   TTO
# 233       948.00      []        [1649]      Cockburn Town
# 234        26.00      []         [688]           Funafuti   TUV
# 242     12189.00      []         [678]          Port Vila   VAN
# 245       142.00      []         [681]           Mata-Utu
#
#                                             currencies  \
# 1     [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]
# 4    [{'code': 'USD', 'name': 'United State Dollar'...
# 7    [{'code': 'XCD', 'name': 'East Caribbean dolla...
# 8    [{'code': 'AUD', 'name': 'Australian dollar', ...
# 9    [{'code': 'XCD', 'name': 'East Caribbean dolla...
# 12   [{'code': 'AWG', 'name': 'Aruban florin', 'sym...
# 13   [{'code': 'AUD', 'name': 'Australian dollar', ...
# 16   [{'code': 'BSD', 'name': 'Bahamian dollar', 's...
# 17   [{'code': 'BHD', 'name': 'Bahraini dinar', 'sy...
# 19   [{'code': 'BBD', 'name': 'Barbadian dollar', '...
# 24   [{'code': 'BMD', 'name': 'Bermudian dollar', '...
# 27   [{'code': 'USD', 'name': 'United States dollar...
# 30   [{'code': 'NOK', 'name': 'Norwegian krone', 's...
# 32   [{'code': 'USD', 'name': 'United States dollar...
# 33   [{'code': 'USD', 'name': 'United States Dollar...
# 34   [{'code': None, 'name': '[D]', 'symbol': '$'},...
# 35   [{'code': 'USD', 'name': 'United States dollar...
# 43   [{'code': 'CVE', 'name': 'Cape Verdean escudo'...
# 44   [{'code': 'KYD', 'name': 'Cayman Islands dolla...
# 49   [{'code': 'AUD', 'name': 'Australian dollar', ...
# 50   [{'code': 'AUD', 'name': 'Australian dollar', ...
# 52   [{'code': 'KMF', 'name': 'Comorian franc', 'sy...
# 55   [{'code': 'NZD', 'name': 'New Zealand dollar',...
# 58   [{'code': 'CUC', 'name': 'Cuban convertible pe...
# 59   [{'code': 'ANG', 'name': 'Netherlands Antillea...
# 64   [{'code': 'XCD', 'name': 'East Caribbean dolla...
# 73   [{'code': 'FKP', 'name': 'Falkland Islands pou...
# 74   [{'code': 'DKK', 'name': 'Danish krone', 'symb...
# 75   [{'code': 'FJD', 'name': 'Fijian dollar', 'sym...
# 79   [{'code': 'XPF', 'name': 'CFP franc', 'symbol'...
# ..                                                 ...
# 159  [{'code': 'NZD', 'name': 'New Zealand dollar',...
# 163  [{'code': 'NZD', 'name': 'New Zealand dollar',...
# 164  [{'code': 'AUD', 'name': 'Australian dollar', ...
# 166  [{'code': 'USD', 'name': 'United States dollar...
# 170  [{'code': '(none)', 'name': '[E]', 'symbol': '...
# 176  [{'code': 'PHP', 'name': 'Philippine peso', 's...
# 177  [{'code': 'NZD', 'name': 'New Zealand dollar',...
# 180  [{'code': 'USD', 'name': 'United States dollar...
# 183   [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]
# 187   [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]
# 188  [{'code': 'SHP', 'name': 'Saint Helena pound',...
# 189  [{'code': 'XCD', 'name': 'East Caribbean dolla...
# 190  [{'code': 'XCD', 'name': 'East Caribbean dolla...
# 192   [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]
# 193  [{'code': 'XCD', 'name': 'East Caribbean dolla...
# 194  [{'code': 'WST', 'name': 'Samoan tālā', 'symbo...
# 196  [{'code': 'STD', 'name': 'São Tomé and Príncip...
# 200  [{'code': 'SCR', 'name': 'Seychellois rupee', ...
# 202  [{'code': 'BND', 'name': 'Brunei dollar', 'sym...
# 206  [{'code': 'SBD', 'name': 'Solomon Islands doll...
# 209  [{'code': 'GBP', 'name': 'British pound', 'sym...
# 216  [{'code': 'NOK', 'name': 'Norwegian krone', 's...
# 221  [{'code': 'TWD', 'name': 'New Taiwan dollar', ...
# 227  [{'code': 'NZD', 'name': 'New Zealand dollar',...
# 228  [{'code': 'TOP', 'name': 'Tongan paʻanga', 'sy...
# 229  [{'code': 'TTD', 'name': 'Trinidad and Tobago ...
# 233  [{'code': 'USD', 'name': 'United States dollar...
# 234  [{'code': 'AUD', 'name': 'Australian dollar', ...
# 242  [{'code': 'VUV', 'name': 'Vanuatu vatu', 'symb...
# 245  [{'code': 'XPF', 'name': 'CFP franc', 'symbol'...
#
#                                            demonym  \
# 1                                         Ålandish
# 4                                  American Samoan
# 7                                       Anguillian
# 8
# 9                               Antiguan, Barbudan
# 12                                          Aruban
# 13                                      Australian
# 16                                        Bahamian
# 17                                        Bahraini
# 19                                       Barbadian
# 24                                       Bermudian
# 27                                           Dutch
# 30
# 32                                          Indian
# 33                                        American
# 34                                 Virgin Islander
# 35                                 Virgin Islander
# 43                                    Cape Verdian
# 44                                       Caymanian
# 49                                Christmas Island
# 50                                  Cocos Islander
# 52                                         Comoran
# 55                                   Cook Islander
# 58                                           Cuban
# 59                                           Dutch
# 64                                       Dominican
# 73                               Falkland Islander
# 74                                         Faroese
# 75                                          Fijian
# 79                               French Polynesian
# ..                                             ...
# 159                                  New Zealander
# 163                                         Niuean
# 164                               Norfolk Islander
# 166                                       American
# 170                                        Palauan
# 176                                       Filipino
# 177                              Pitcairn Islander
# 180                                   Puerto Rican
# 183                                         French
# 187                      Saint Barthélemy Islander
# 188                                 Saint Helenian
# 189                           Kittian and Nevisian
# 190                                   Saint Lucian
# 192                                         French
# 193                               Saint Vincentian
# 194                                         Samoan
# 196                                     Sao Tomean
# 200                                    Seychellois
# 202                                    Singaporean
# 206                               Solomon Islander
# 209  South Georgia and the South Sandwich Islander
# 216                                      Norwegian
# 221                                      Taiwanese
# 227                                      Tokelauan
# 228                                         Tongan
# 229                                    Trinidadian
# 233                      Turks and Caicos Islander
# 234                                       Tuvaluan
# 242                                     Ni-Vanuatu
# 245                     Wallis and Futuna Islander
#
#                            ...                          \
# 1                          ...
# 4                          ...
# 7                          ...
# 8                          ...
# 9                          ...
# 12                         ...
# 13                         ...
# 16                         ...
# 17                         ...
# 19                         ...
# 24                         ...
# 27                         ...
# 30                         ...
# 32                         ...
# 33                         ...
# 34                         ...
# 35                         ...
# 43                         ...
# 44                         ...
# 49                         ...
# 50                         ...
# 52                         ...
# 55                         ...
# 58                         ...
# 59                         ...
# 64                         ...
# 73                         ...
# 74                         ...
# 75                         ...
# 79                         ...
# ..                         ...
# 159                        ...
# 163                        ...
# 164                        ...
# 166                        ...
# 170                        ...
# 176                        ...
# 177                        ...
# 180                        ...
# 183                        ...
# 187                        ...
# 188                        ...
# 189                        ...
# 190                        ...
# 192                        ...
# 193                        ...
# 194                        ...
# 196                        ...
# 200                        ...
# 202                        ...
# 206                        ...
# 209                        ...
# 216                        ...
# 221                        ...
# 227                        ...
# 228                        ...
# 229                        ...
# 233                        ...
# 234                        ...
# 242                        ...
# 245                        ...
#
#                                              name  \
# 1                                   Åland Islands
# 4                                  American Samoa
# 7                                        Anguilla
# 8                                      Antarctica
# 9                             Antigua and Barbuda
# 12                                          Aruba
# 13                                      Australia
# 16                                        Bahamas
# 17                                        Bahrain
# 19                                       Barbados
# 24                                        Bermuda
# 27               Bonaire, Sint Eustatius and Saba
# 30                                  Bouvet Island
# 32                 British Indian Ocean Territory
# 33           United States Minor Outlying Islands
# 34                       Virgin Islands (British)
# 35                          Virgin Islands (U.S.)
# 43                                     Cabo Verde
# 44                                 Cayman Islands
# 49                               Christmas Island
# 50                        Cocos (Keeling) Islands
# 52                                        Comoros
# 55                                   Cook Islands
# 58                                           Cuba
# 59                                        Curaçao
# 64                                       Dominica
# 73                    Falkland Islands (Malvinas)
# 74                                  Faroe Islands
# 75                                           Fiji
# 79                               French Polynesia
# ..                                            ...
# 159                                   New Zealand
# 163                                          Niue
# 164                                Norfolk Island
# 166                      Northern Mariana Islands
# 170                                         Palau
# 176                                   Philippines
# 177                                      Pitcairn
# 180                                   Puerto Rico
# 183                                       Réunion
# 187                              Saint Barthélemy
# 188  Saint Helena, Ascension and Tristan da Cunha
# 189                         Saint Kitts and Nevis
# 190                                   Saint Lucia
# 192                     Saint Pierre and Miquelon
# 193              Saint Vincent and the Grenadines
# 194                                         Samoa
# 196                         Sao Tome and Principe
# 200                                    Seychelles
# 202                                     Singapore
# 206                               Solomon Islands
# 209  South Georgia and the South Sandwich Islands
# 216                        Svalbard and Jan Mayen
# 221                                        Taiwan
# 227                                       Tokelau
# 228                                         Tonga
# 229                           Trinidad and Tobago
# 233                      Turks and Caicos Islands
# 234                                        Tuvalu
# 242                                       Vanuatu
# 245                             Wallis and Futuna
#
#                                nativeName numericCode population    region  \
# 1                                   Åland         248      28875    Europe
# 4                          American Samoa         016      57100   Oceania
# 7                                Anguilla         660      13452  Americas
# 8                              Antarctica         010       1000     Polar
# 9                     Antigua and Barbuda         028      86295  Americas
# 12                                  Aruba         533     107394  Americas
# 13                              Australia         036   24117360   Oceania
# 16                                Bahamas         044     378040  Americas
# 17                               ‏البحرين         048    1404900      Asia
# 19                               Barbados         052     285000  Americas
# 24                                Bermuda         060      61954  Americas
# 27                                Bonaire         535      17408  Americas
# 30                              Bouvetøya         074          0
# 32         British Indian Ocean Territory         086       3000    Africa
# 33   United States Minor Outlying Islands         581        300  Americas
# 34                 British Virgin Islands         092      28514  Americas
# 35    Virgin Islands of the United States         850     114743  Americas
# 43                             Cabo Verde         132     531239    Africa
# 44                         Cayman Islands         136      58238  Americas
# 49                       Christmas Island         162       2072   Oceania
# 50                Cocos (Keeling) Islands         166        550   Oceania
# 52                                 Komori         174     806153    Africa
# 55                           Cook Islands         184      18100   Oceania
# 58                                   Cuba         192   11239004  Americas
# 59                                Curaçao         531     154843  Americas
# 64                               Dominica         212      71293  Americas
# 73                       Falkland Islands         238       2563  Americas
# 74                                Føroyar         234      49376    Europe
# 75                                   Fiji         242     867000   Oceania
# 79                    Polynésie française         258     271800   Oceania
# ..                                    ...         ...        ...       ...
# 159                           New Zealand         554    4697854   Oceania
# 163                                  Niuē         570       1470   Oceania
# 164                        Norfolk Island         574       2302   Oceania
# 166              Northern Mariana Islands         580      56940   Oceania
# 170                                 Palau         585      17950   Oceania
# 176                             Pilipinas         608  103279800      Asia
# 177                      Pitcairn Islands         612         56   Oceania
# 180                           Puerto Rico         630    3474182  Americas
# 183                            La Réunion         638     840974    Africa
# 187                      Saint-Barthélemy         652       9417  Americas
# 188                          Saint Helena         654       4255    Africa
# 189                 Saint Kitts and Nevis         659      46204  Americas
# 190                           Saint Lucia         662     186000  Americas
# 192              Saint-Pierre-et-Miquelon         666       6069  Americas
# 193      Saint Vincent and the Grenadines         670     109991  Americas
# 194                                 Samoa         882     194899   Oceania
# 196                   São Tomé e Príncipe         678     187356    Africa
# 200                            Seychelles         690      91400    Africa
# 202                             Singapore         702    5535000      Asia
# 206                       Solomon Islands         090     642000   Oceania
# 209                         South Georgia         239         30  Americas
# 216                 Svalbard og Jan Mayen         744       2562    Europe
# 221                                    臺灣         158   23503349      Asia
# 227                               Tokelau         772       1411   Oceania
# 228                                 Tonga         776     103252   Oceania
# 229                   Trinidad and Tobago         780    1349667  Americas
# 233              Turks and Caicos Islands         796      31458  Americas
# 234                                Tuvalu         798      10640   Oceania
# 242                               Vanuatu         548     277500   Oceania
# 245                      Wallis et Futuna         876      11750   Oceania
#
#                                          regionalBlocs  \
# 1    [{'acronym': 'EU', 'name': 'European Union', '...
# 4                                                   []
# 7                                                   []
# 8                                                   []
# 9    [{'acronym': 'CARICOM', 'name': 'Caribbean Com...
# 12                                                  []
# 13                                                  []
# 16   [{'acronym': 'CARICOM', 'name': 'Caribbean Com...
# 17   [{'acronym': 'AL', 'name': 'Arab League', 'oth...
# 19   [{'acronym': 'CARICOM', 'name': 'Caribbean Com...
# 24                                                  []
# 27                                                  []
# 30                                                  []
# 32   [{'acronym': 'AU', 'name': 'African Union', 'o...
# 33                                                  []
# 34                                                  []
# 35                                                  []
# 43   [{'acronym': 'AU', 'name': 'African Union', 'o...
# 44                                                  []
# 49                                                  []
# 50                                                  []
# 52   [{'acronym': 'AU', 'name': 'African Union', 'o...
# 55                                                  []
# 58                                                  []
# 59                                                  []
# 64                                                  []
# 73   [{'acronym': 'USAN', 'name': 'Union of South A...
# 74   [{'acronym': 'EU', 'name': 'European Union', '...
# 75                                                  []
# 79                                                  []
# ..                                                 ...
# 159                                                 []
# 163                                                 []
# 164                                                 []
# 166                                                 []
# 170                                                 []
# 176  [{'acronym': 'ASEAN', 'name': 'Association of ...
# 177                                                 []
# 180                                                 []
# 183  [{'acronym': 'AU', 'name': 'African Union', 'o...
# 187                                                 []
# 188  [{'acronym': 'AU', 'name': 'African Union', 'o...
# 189  [{'acronym': 'CARICOM', 'name': 'Caribbean Com...
# 190  [{'acronym': 'CARICOM', 'name': 'Caribbean Com...
# 192                                                 []
# 193  [{'acronym': 'CARICOM', 'name': 'Caribbean Com...
# 194                                                 []
# 196  [{'acronym': 'AU', 'name': 'African Union', 'o...
# 200  [{'acronym': 'AU', 'name': 'African Union', 'o...
# 202  [{'acronym': 'ASEAN', 'name': 'Association of ...
# 206                                                 []
# 209  [{'acronym': 'USAN', 'name': 'Union of South A...
# 216                                                 []
# 221                                                 []
# 227                                                 []
# 228                                                 []
# 229  [{'acronym': 'CARICOM', 'name': 'Caribbean Com...
# 233                                                 []
# 234                                                 []
# 242                                                 []
# 245                                                 []
#
#                      subregion  \
# 1              Northern Europe
# 4                    Polynesia
# 7                    Caribbean
# 8
# 9                    Caribbean
# 12                   Caribbean
# 13   Australia and New Zealand
# 16                   Caribbean
# 17                Western Asia
# 19                   Caribbean
# 24            Northern America
# 27                   Caribbean
# 30
# 32              Eastern Africa
# 33            Northern America
# 34                   Caribbean
# 35                   Caribbean
# 43              Western Africa
# 44                   Caribbean
# 49   Australia and New Zealand
# 50   Australia and New Zealand
# 52              Eastern Africa
# 55                   Polynesia
# 58                   Caribbean
# 59                   Caribbean
# 64                   Caribbean
# 73               South America
# 74             Northern Europe
# 75                   Melanesia
# 79                   Polynesia
# ..                         ...
# 159  Australia and New Zealand
# 163                  Polynesia
# 164  Australia and New Zealand
# 166                 Micronesia
# 170                 Micronesia
# 176         South-Eastern Asia
# 177                  Polynesia
# 180                  Caribbean
# 183             Eastern Africa
# 187                  Caribbean
# 188             Western Africa
# 189                  Caribbean
# 190                  Caribbean
# 192           Northern America
# 193                  Caribbean
# 194                  Polynesia
# 196              Middle Africa
# 200             Eastern Africa
# 202         South-Eastern Asia
# 206                  Melanesia
# 209              South America
# 216            Northern Europe
# 221               Eastern Asia
# 227                  Polynesia
# 228                  Polynesia
# 229                  Caribbean
# 233                  Caribbean
# 234                  Polynesia
# 242                  Melanesia
# 245                  Polynesia
#
#                                              timezones topLevelDomain  \
# 1                                          [UTC+02:00]          [.ax]
# 4                                          [UTC-11:00]          [.as]
# 7                                          [UTC-04:00]          [.ai]
# 8    [UTC-03:00, UTC+03:00, UTC+05:00, UTC+06:00, U...          [.aq]
# 9                                          [UTC-04:00]          [.ag]
# 12                                         [UTC-04:00]          [.aw]
# 13   [UTC+05:00, UTC+06:30, UTC+07:00, UTC+08:00, U...          [.au]
# 16                                         [UTC-05:00]          [.bs]
# 17                                         [UTC+03:00]          [.bh]
# 19                                         [UTC-04:00]          [.bb]
# 24                                         [UTC-04:00]          [.bm]
# 27                                         [UTC-04:00]     [.an, .nl]
# 30                                         [UTC+01:00]          [.bv]
# 32                                         [UTC+06:00]          [.io]
# 33                   [UTC-11:00, UTC-10:00, UTC+12:00]          [.us]
# 34                                         [UTC-04:00]          [.vg]
# 35                                         [UTC-04:00]          [.vi]
# 43                                         [UTC-01:00]          [.cv]
# 44                                         [UTC-05:00]          [.ky]
# 49                                         [UTC+07:00]          [.cx]
# 50                                         [UTC+06:30]          [.cc]
# 52                                         [UTC+03:00]          [.km]
# 55                                         [UTC-10:00]          [.ck]
# 58                                         [UTC-05:00]          [.cu]
# 59                                         [UTC-04:00]          [.cw]
# 64                                         [UTC-04:00]          [.dm]
# 73                                         [UTC-04:00]          [.fk]
# 74                                         [UTC+00:00]          [.fo]
# 75                                         [UTC+12:00]          [.fj]
# 79                   [UTC-10:00, UTC-09:30, UTC-09:00]          [.pf]
# ..                                                 ...            ...
# 159  [UTC-11:00, UTC-10:00, UTC+12:00, UTC+12:45, U...          [.nz]
# 163                                        [UTC-11:00]          [.nu]
# 164                                        [UTC+11:30]          [.nf]
# 166                                        [UTC+10:00]          [.mp]
# 170                                        [UTC+09:00]          [.pw]
# 176                                        [UTC+08:00]          [.ph]
# 177                                        [UTC-08:00]          [.pn]
# 180                                        [UTC-04:00]          [.pr]
# 183                                        [UTC+04:00]          [.re]
# 187                                        [UTC-04:00]          [.bl]
# 188                                        [UTC+00:00]          [.sh]
# 189                                        [UTC-04:00]          [.kn]
# 190                                        [UTC-04:00]          [.lc]
# 192                                        [UTC-03:00]          [.pm]
# 193                                        [UTC-04:00]          [.vc]
# 194                                        [UTC+13:00]          [.ws]
# 196                                              [UTC]          [.st]
# 200                                        [UTC+04:00]          [.sc]
# 202                                        [UTC+08:00]          [.sg]
# 206                                        [UTC+11:00]          [.sb]
# 209                                        [UTC-02:00]          [.gs]
# 216                                        [UTC+01:00]          [.sj]
# 221                                        [UTC+08:00]          [.tw]
# 227                                        [UTC+13:00]          [.tk]
# 228                                        [UTC+13:00]          [.to]
# 229                                        [UTC-04:00]          [.tt]
# 233                                        [UTC-04:00]          [.tc]
# 234                                        [UTC+12:00]          [.tv]
# 242                                        [UTC+11:00]          [.vu]
# 245                                        [UTC+12:00]          [.wf]
#
#                                           translations
# 1    {'de': 'Åland', 'es': 'Alandia', 'fr': 'Åland'...
# 4    {'de': 'Amerikanisch-Samoa', 'es': 'Samoa Amer...
# 7    {'de': 'Anguilla', 'es': 'Anguilla', 'fr': 'An...
# 8    {'de': 'Antarktika', 'es': 'Antártida', 'fr': ...
# 9    {'de': 'Antigua und Barbuda', 'es': 'Antigua y...
# 12   {'de': 'Aruba', 'es': 'Aruba', 'fr': 'Aruba', ...
# 13   {'de': 'Australien', 'es': 'Australia', 'fr': ...
# 16   {'de': 'Bahamas', 'es': 'Bahamas', 'fr': 'Baha...
# 17   {'de': 'Bahrain', 'es': 'Bahrein', 'fr': 'Bahr...
# 19   {'de': 'Barbados', 'es': 'Barbados', 'fr': 'Ba...
# 24   {'de': 'Bermuda', 'es': 'Bermudas', 'fr': 'Ber...
# 27   {'de': 'Bonaire, Sint Eustatius und Saba', 'es...
# 30   {'de': 'Bouvetinsel', 'es': 'Isla Bouvet', 'fr...
# 32   {'de': 'Britisches Territorium im Indischen Oz...
# 33   {'de': 'Kleinere Inselbesitzungen der Vereinig...
# 34   {'de': 'Britische Jungferninseln', 'es': 'Isla...
# 35   {'de': 'Amerikanische Jungferninseln', 'es': '...
# 43   {'de': 'Kap Verde', 'es': 'Cabo Verde', 'fr': ...
# 44   {'de': 'Kaimaninseln', 'es': 'Islas Caimán', '...
# 49   {'de': 'Weihnachtsinsel', 'es': 'Isla de Navid...
# 50   {'de': 'Kokosinseln', 'es': 'Islas Cocos o Isl...
# 52   {'de': 'Union der Komoren', 'es': 'Comoras', '...
# 55   {'de': 'Cookinseln', 'es': 'Islas Cook', 'fr':...
# 58   {'de': 'Kuba', 'es': 'Cuba', 'fr': 'Cuba', 'ja...
# 59   {'de': 'Curaçao', 'es': None, 'fr': 'Curaçao',...
# 64   {'de': 'Dominica', 'es': 'Dominica', 'fr': 'Do...
# 73   {'de': 'Falklandinseln', 'es': 'Islas Malvinas...
# 74   {'de': 'Färöer-Inseln', 'es': 'Islas Faroe', '...
# 75   {'de': 'Fidschi', 'es': 'Fiyi', 'fr': 'Fidji',...
# 79   {'de': 'Französisch-Polynesien', 'es': 'Poline...
# ..                                                 ...
# 159  {'de': 'Neuseeland', 'es': 'Nueva Zelanda', 'f...
# 163  {'de': 'Niue', 'es': 'Niue', 'fr': 'Niue', 'ja...
# 164  {'de': 'Norfolkinsel', 'es': 'Isla de Norfolk'...
# 166  {'de': 'Nördliche Marianen', 'es': 'Islas Mari...
# 170  {'de': 'Palau', 'es': 'Palau', 'fr': 'Palaos',...
# 176  {'de': 'Philippinen', 'es': 'Filipinas', 'fr':...
# 177  {'de': 'Pitcairn', 'es': 'Islas Pitcairn', 'fr...
# 180  {'de': 'Puerto Rico', 'es': 'Puerto Rico', 'fr...
# 183  {'de': 'Réunion', 'es': 'Reunión', 'fr': 'Réun...
# 187  {'de': 'Saint-Barthélemy', 'es': 'San Bartolom...
# 188  {'de': 'Sankt Helena', 'es': 'Santa Helena', '...
# 189  {'de': 'St. Kitts und Nevis', 'es': 'San Crist...
# 190  {'de': 'Saint Lucia', 'es': 'Santa Lucía', 'fr...
# 192  {'de': 'Saint-Pierre und Miquelon', 'es': 'San...
# 193  {'de': 'Saint Vincent und die Grenadinen', 'es...
# 194  {'de': 'Samoa', 'es': 'Samoa', 'fr': 'Samoa', ...
# 196  {'de': 'São Tomé und Príncipe', 'es': 'Santo T...
# 200  {'de': 'Seychellen', 'es': 'Seychelles', 'fr':...
# 202  {'de': 'Singapur', 'es': 'Singapur', 'fr': 'Si...
# 206  {'de': 'Salomonen', 'es': 'Islas Salomón', 'fr...
# 209  {'de': 'Südgeorgien und die Südlichen Sandwich...
# 216  {'de': 'Svalbard und Jan Mayen', 'es': 'Islas ...
# 221  {'de': 'Taiwan', 'es': 'Taiwán', 'fr': 'Taïwan...
# 227  {'de': 'Tokelau', 'es': 'Islas Tokelau', 'fr':...
# 228  {'de': 'Tonga', 'es': 'Tonga', 'fr': 'Tonga', ...
# 229  {'de': 'Trinidad und Tobago', 'es': 'Trinidad ...
# 233  {'de': 'Turks- und Caicosinseln', 'es': 'Islas...
# 234  {'de': 'Tuvalu', 'es': 'Tuvalu', 'fr': 'Tuvalu...
# 242  {'de': 'Vanuatu', 'es': 'Vanuatu', 'fr': 'Vanu...
# 245  {'de': 'Wallis und Futuna', 'es': 'Wallis y Fu...
#
# [84 rows x 24 columns]

# %%
def  has_border(lst):
    return len(lst) > 0

def  has_no_border(lst):
     return  len(lst) == 0

# %%
cdf[cdf['borders'].apply(has_no_border)].head()
# Out:
#   alpha2Code alpha3Code                                       altSpellings  \
# 1         AX        ALA                    [AX, Aaland, Aland, Ahvenanmaa]
# 4         AS        ASM  [AS, Amerika Sāmoa, Amelika Sāmoa, Sāmoa Amelika]
# 7         AI        AIA                                               [AI]
# 8         AQ        ATA                                                 []
# 9         AG        ATG                                               [AG]
#
#          area borders callingCodes       capital cioc  \
# 1      1580.0      []        [358]     Mariehamn
# 4       199.0      []       [1684]     Pago Pago  ASA
# 7        91.0      []       [1264]    The Valley
# 8  14000000.0      []        [672]
# 9       442.0      []       [1268]  Saint John's  ANT
#
#                                           currencies             demonym  \
# 1   [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]            Ålandish
# 4  [{'code': 'USD', 'name': 'United State Dollar'...     American Samoan
# 7  [{'code': 'XCD', 'name': 'East Caribbean dolla...          Anguillian
# 8  [{'code': 'AUD', 'name': 'Australian dollar', ...
# 9  [{'code': 'XCD', 'name': 'East Caribbean dolla...  Antiguan, Barbudan
#
#                          ...                                         name  \
# 1                        ...                                Åland Islands
# 4                        ...                               American Samoa
# 7                        ...                                     Anguilla
# 8                        ...                                   Antarctica
# 9                        ...                          Antigua and Barbuda
#
#             nativeName numericCode population    region  \
# 1                Åland         248      28875    Europe
# 4       American Samoa         016      57100   Oceania
# 7             Anguilla         660      13452  Americas
# 8           Antarctica         010       1000     Polar
# 9  Antigua and Barbuda         028      86295  Americas
#
#                                        regionalBlocs        subregion  \
# 1  [{'acronym': 'EU', 'name': 'European Union', '...  Northern Europe
# 4                                                 []        Polynesia
# 7                                                 []        Caribbean
# 8                                                 []
# 9  [{'acronym': 'CARICOM', 'name': 'Caribbean Com...        Caribbean
#
#                                            timezones topLevelDomain  \
# 1                                        [UTC+02:00]          [.ax]
# 4                                        [UTC-11:00]          [.as]
# 7                                        [UTC-04:00]          [.ai]
# 8  [UTC-03:00, UTC+03:00, UTC+05:00, UTC+06:00, U...          [.aq]
# 9                                        [UTC-04:00]          [.ag]
#
#                                         translations
# 1  {'de': 'Åland', 'es': 'Alandia', 'fr': 'Åland'...
# 4  {'de': 'Amerikanisch-Samoa', 'es': 'Samoa Amer...
# 7  {'de': 'Anguilla', 'es': 'Anguilla', 'fr': 'An...
# 8  {'de': 'Antarktika', 'es': 'Antártida', 'fr': ...
# 9  {'de': 'Antigua und Barbuda', 'es': 'Antigua y...
#
# [5 rows x 24 columns]

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 24 columns):
# alpha2Code        250 non-null object
# alpha3Code        250 non-null object
# altSpellings      250 non-null object
# area              240 non-null float64
# borders           250 non-null object
# callingCodes      250 non-null object
# capital           250 non-null object
# cioc              247 non-null object
# currencies        250 non-null object
# demonym           250 non-null object
# flag              250 non-null object
# gini              153 non-null float64
# languages         250 non-null object
# latlng            250 non-null object
# name              250 non-null object
# nativeName        250 non-null object
# numericCode       249 non-null object
# population        250 non-null int64
# region            250 non-null object
# regionalBlocs     250 non-null object
# subregion         250 non-null object
# timezones         250 non-null object
# topLevelDomain    250 non-null object
# translations      250 non-null object
# dtypes: float64(2), int64(1), object(21)
# memory usage: 47.0+ KB

# %%
cdf['area'].sort_values(ascending=False).head()

# %%
top5 =
# Out:
# 185    17124442.0
# 8      14000000.0
# 42      9984670.0
# 48      9640011.0
# 239     9629091.0
# Name: area, dtype: float64

# %%
cdf.loc[top5.index,['name','region','area','population']]
# Out:
#                          name    region        area  population
# 185        Russian Federation    Europe  17124442.0   146599183
# 8                  Antarctica     Polar  14000000.0        1000
# 42                     Canada  Americas   9984670.0    36155487
# 48                      China      Asia   9640011.0  1377422166
# 239  United States of America  Americas   9629091.0   323947000

# %%
cdf[ (cdf['region'] == 'Asia') & (cdf['area'] > 3000000) ]
# Out:
#     alpha2Code alpha3Code                                       altSpellings  \
# 48          CN        CHN  [CN, Zhōngguó, Zhongguo, Zhonghua, People's Re...
# 104         IN        IND   [IN, Bhārat, Republic of India, Bharat Ganrajya]
#
#           area                                            borders  \
# 48   9640011.0  [AFG, BTN, MMR, HKG, IND, KAZ, PRK, KGZ, LAO, ...
# 104  3287590.0           [AFG, BGD, BTN, MMR, CHN, NPL, PAK, LKA]
#
#     callingCodes    capital cioc  \
# 48          [86]    Beijing  CHN
# 104         [91]  New Delhi  IND
#
#                                             currencies  demonym  \
# 48   [{'code': 'CNY', 'name': 'Chinese yuan', 'symb...  Chinese
# 104  [{'code': 'INR', 'name': 'Indian rupee', 'symb...   Indian
#
#                            ...                           name  nativeName  \
# 48                         ...                          China          中国
# 104                        ...                          India        भारत
#
#     numericCode  population region  \
# 48          156  1377422166   Asia
# 104         356  1295210000   Asia
#
#                                          regionalBlocs      subregion  \
# 48                                                  []   Eastern Asia
# 104  [{'acronym': 'SAARC', 'name': 'South Asian Ass...  Southern Asia
#
#        timezones topLevelDomain  \
# 48   [UTC+08:00]          [.cn]
# 104  [UTC+05:30]          [.in]
#
#                                           translations
# 48   {'de': 'China', 'es': 'China', 'fr': 'Chine', ...
# 104  {'de': 'Indien', 'es': 'India', 'fr': 'Inde', ...
#
# [2 rows x 24 columns]

# %%
cdf.at[0,'alpha3Code']
# Out:
# 'AFG'

# %%
cdf.sample(n=10)
# Out:
#     alpha2Code alpha3Code                                       altSpellings  \
# 60          CY        CYP  [CY, Kýpros, Kıbrıs, Republic of Cyprus, Κυπρι...
# 179         PT        PRT  [PT, Portuguesa, Portuguese Republic, Repúblic...
# 191         MF        MAF  [MF, Collectivity of Saint Martin, Collectivit...
# 135         MY        MYS                                               [MY]
# 217         SZ        SWZ  [SZ, weSwatini, Swatini, Ngwane, Kingdom of Sw...
# 131         MO        MAC  [MO, 澳门, Macao Special Administrative Region o...
# 157         NL        NLD                           [NL, Holland, Nederland]
# 54          CD        COD                [CD, DR Congo, Congo-Kinshasa, DRC]
# 6           AO        AGO    [AO, República de Angola, ʁɛpublika de an'ɡɔla]
# 10          AR        ARG      [AR, Argentine Republic, República Argentina]
#
#           area                                        borders callingCodes  \
# 60      9251.0                                          [GBR]        [357]
# 179    92090.0                                          [ESP]        [351]
# 191       53.0                                     [SXM, NLD]        [590]
# 135   330803.0                                [BRN, IDN, THA]         [60]
# 217    17364.0                                     [MOZ, ZAF]        [268]
# 131       30.0                                          [CHN]        [853]
# 157    41850.0                                     [BEL, DEU]         [31]
# 54   2344858.0  [AGO, BDI, CAF, COG, RWA, SSD, TZA, UGA, ZMB]        [243]
# 6    1246700.0                           [COG, COD, ZMB, NAM]        [244]
# 10   2780400.0                      [BOL, BRA, CHL, PRY, URY]         [54]
#
#           capital cioc                                         currencies  \
# 60        Nicosia  CYP   [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]
# 179        Lisbon  POR   [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]
# 191       Marigot        [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]
# 135  Kuala Lumpur  MAS  [{'code': 'MYR', 'name': 'Malaysian ringgit', ...
# 217       Lobamba  SWZ  [{'code': 'SZL', 'name': 'Swazi lilangeni', 's...
# 131                     [{'code': 'MOP', 'name': 'Macanese pataca', 's...
# 157     Amsterdam  NED   [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]
# 54       Kinshasa  COD  [{'code': 'CDF', 'name': 'Congolese franc', 's...
# 6          Luanda  ANG  [{'code': 'AOA', 'name': 'Angolan kwanza', 'sy...
# 10   Buenos Aires  ARG  [{'code': 'ARS', 'name': 'Argentine peso', 'sy...
#
#                    demonym                        ...                          \
# 60                 Cypriot                        ...
# 179             Portuguese                        ...
# 191  Saint Martin Islander                        ...
# 135              Malaysian                        ...
# 217                  Swazi                        ...
# 131                Chinese                        ...
# 157                  Dutch                        ...
# 54               Congolese                        ...
# 6                  Angolan                        ...
# 10             Argentinean                        ...
#
#                                    name                        nativeName  \
# 60                               Cyprus                            Κύπρος
# 179                            Portugal                          Portugal
# 191          Saint Martin (French part)                      Saint-Martin
# 135                            Malaysia                          Malaysia
# 217                           Swaziland                         Swaziland
# 131                               Macao                                澳門
# 157                         Netherlands                         Nederland
# 54   Congo (Democratic Republic of the)  République démocratique du Congo
# 6                                Angola                            Angola
# 10                            Argentina                         Argentina
#
#     numericCode population    region  \
# 60          196     847000    Europe
# 179         620   10374822    Europe
# 191         663      36979  Americas
# 135         458   31405416      Asia
# 217         748    1132657    Africa
# 131         446     649100      Asia
# 157         528   17019800    Europe
# 54          180   85026000    Africa
# 6           024   25868000    Africa
# 10          032   43590400  Americas
#
#                                          regionalBlocs           subregion  \
# 60   [{'acronym': 'EU', 'name': 'European Union', '...     Southern Europe
# 179  [{'acronym': 'EU', 'name': 'European Union', '...     Southern Europe
# 191                                                 []           Caribbean
# 135  [{'acronym': 'ASEAN', 'name': 'Association of ...  South-Eastern Asia
# 217  [{'acronym': 'AU', 'name': 'African Union', 'o...     Southern Africa
# 131                                                 []        Eastern Asia
# 157  [{'acronym': 'EU', 'name': 'European Union', '...      Western Europe
# 54   [{'acronym': 'AU', 'name': 'African Union', 'o...       Middle Africa
# 6    [{'acronym': 'AU', 'name': 'African Union', 'o...       Middle Africa
# 10   [{'acronym': 'USAN', 'name': 'Union of South A...       South America
#
#                   timezones   topLevelDomain  \
# 60              [UTC+02:00]            [.cy]
# 179        [UTC-01:00, UTC]            [.pt]
# 191             [UTC-04:00]  [.mf, .fr, .gp]
# 135             [UTC+08:00]            [.my]
# 217             [UTC+02:00]            [.sz]
# 131             [UTC+08:00]            [.mo]
# 157  [UTC-04:00, UTC+01:00]            [.nl]
# 54   [UTC+01:00, UTC+02:00]            [.cd]
# 6               [UTC+01:00]            [.ao]
# 10              [UTC-03:00]            [.ar]
#
#                                           translations
# 60   {'de': 'Zypern', 'es': 'Chipre', 'fr': 'Chypre...
# 179  {'de': 'Portugal', 'es': 'Portugal', 'fr': 'Po...
# 191  {'de': 'Saint Martin', 'es': 'Saint Martin', '...
# 135  {'de': 'Malaysia', 'es': 'Malasia', 'fr': 'Mal...
# 217  {'de': 'Swasiland', 'es': 'Suazilandia', 'fr':...
# 131  {'de': 'Macao', 'es': 'Macao', 'fr': 'Macao', ...
# 157  {'de': 'Niederlande', 'es': 'Países Bajos', 'f...
# 54   {'de': 'Kongo (Dem. Rep.)', 'es': 'Congo (Rep....
# 6    {'de': 'Angola', 'es': 'Angola', 'fr': 'Angola...
# 10   {'de': 'Argentinien', 'es': 'Argentina', 'fr':...
#
# [10 rows x 24 columns]

# %%
cdf[ ['name','capital','region']].isin({'region': ['Asia','Africa']})
# Out:
#       name  capital  region
# 0    False    False    True
# 1    False    False   False
# 2    False    False   False
# 3    False    False    True
# 4    False    False   False
# 5    False    False   False
# 6    False    False    True
# 7    False    False   False
# 8    False    False   False
# 9    False    False   False
# 10   False    False   False
# 11   False    False    True
# 12   False    False   False
# 13   False    False   False
# 14   False    False   False
# 15   False    False    True
# 16   False    False   False
# 17   False    False    True
# 18   False    False    True
# 19   False    False   False
# 20   False    False   False
# 21   False    False   False
# 22   False    False   False
# 23   False    False    True
# 24   False    False   False
# 25   False    False    True
# 26   False    False   False
# 27   False    False   False
# 28   False    False   False
# 29   False    False    True
# ..     ...      ...     ...
# 220  False    False    True
# 221  False    False    True
# 222  False    False    True
# 223  False    False    True
# 224  False    False    True
# 225  False    False    True
# 226  False    False    True
# 227  False    False   False
# 228  False    False   False
# 229  False    False   False
# 230  False    False    True
# 231  False    False    True
# 232  False    False    True
# 233  False    False   False
# 234  False    False   False
# 235  False    False    True
# 236  False    False   False
# 237  False    False    True
# 238  False    False   False
# 239  False    False   False
# 240  False    False   False
# 241  False    False    True
# 242  False    False   False
# 243  False    False   False
# 244  False    False    True
# 245  False    False   False
# 246  False    False    True
# 247  False    False    True
# 248  False    False    True
# 249  False    False    True
#
# [250 rows x 3 columns]
